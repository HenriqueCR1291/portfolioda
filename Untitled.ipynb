# %%
#!pip install selenium
#!pip install webdriver-manager

# %%
import re
import time
import requests

import pandas as pd

from bs4                            import BeautifulSoup
from selenium                       import webdriver
from bs4.element                    import CData
from urllib.request                 import Request, urlopen
from webdriver_manager.chrome       import ChromeDriverManager
from selenium.webdriver.common.by   import By
from selenium.webdriver.common.keys import Keys

# %%
#driver = webdriver.Chrome(ChromeDriverManager().install())
#driver.get('https://www.ameximoveis.com.br/categoria')
#time.sleep(5)

#previous_height = driver.execute_script('return document.body.scrollHeight')

#while True:
#    driver.execute_script('window.scrollBy(0,document.body.scrollHeight)')
    
#    time.sleep(5)
    
#    new_height = driver.execute_script('return document.body.scrollHeight')
#    if new_height == previous_height:
#        break
#    previous_height = new_height

#browser.close()

# %%
#driver = webdriver.Chrome(ChromeDriverManager().install())
#driver.get('https://www.ameximoveis.com.br/categoria')
#time.sleep(5)

#element = driver.find_element(By.XPATH,'//footer')

#element.send_keys(Keys.PAGE_DOWN)

# %%
headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.106 Safari/537.36'}
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get('https://www.ameximoveis.com.br/categoria')
time.sleep(5)
element = driver.find_element(By.XPATH,'//footer')
previous_height = driver.execute_script('return document.body.scrollHeight')
#print(previous_height)

while driver.find_element(By.XPATH,'//footer'):
    driver.execute_script("arguments[0].scrollIntoView();",element)
    #divs = driver.find_element(By.XPATH,'//footer').text
    time.sleep(5)
    new_height = driver.execute_script('return document.body.scrollHeight')
    #print(new_height)
    if new_height <= previous_height:
        resposta = driver.page_source
        site = BeautifulSoup(resposta, 'html.parser')
        print(site.prettify())
        close.browser()
        #print('OK - Break')
        break
    else:
        #print('OK - Continue')
        previous_height = new_height
        continue
# Out:
# C:\Users\Henrique\AppData\Local\Temp\ipykernel_12104\1376617655.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# <html lang="pt-br">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Amex Imóveis - Encontre o seu lugar
#   </title>
#   <meta content="index,follow" name="robots"/>
#   <meta content="index,follow" name="googlebot"/>
#   <meta content="Compre ou alugue com agilidade, segurança e sem burocracia" name="description"/>
#   <meta content="Encontre o seu lugar" property="og:title"/>
#   <meta content="Compre ou alugue com agilidade, segurança e sem burocracia" property="og:description"/>
#   <meta content="/" property="og:url"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://www.ameximoveis.com.br/_app/images/amex-og.png" property="og:image"/>
#   <meta content="Logo da Encontre o seu lugar" property="og:image:alt"/>
#   <meta content="pt_BR" property="og:locale"/>
#   <meta content="Encontre o seu lugar" property="og:site_name"/>
#   <meta content="tbggz9gafmsxtqee5pe9fx4zqqt076" name="facebook-domain-verification"/>
#   <link href="https://www.ameximoveis.com.br/_app/images/favicon.png" rel="icon" type="image/png"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="https://www.ameximoveis.com.br/_app/scss/base.css?v=" rel="stylesheet"/>
#   <link href="https://www.ameximoveis.com.br/_app/bower_components/swiper/dist/css/swiper.min.css" rel="stylesheet"/>
#   <link href="https://www.ameximoveis.com.br/_app/bower_components/select2/dist/css/select2.min.css" rel="stylesheet"/>
#   <link href="https://www.ameximoveis.com.br/_app/bower_components/fancybox/dist/jquery.fancybox.min.css" rel="stylesheet"/>
#   <!-- Hotjar Tracking Code for http://www.amex.com.br -->
#   <script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript">
#   </script>
#   <script async="" src="https://www.googleadservices.com/pagead/conversion_async.js" type="text/javascript">
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-EJX4XCNSDM&amp;l=dataLayer&amp;cx=c" type="text/javascript">
#   </script>
#   <script async="" src="https://connect.facebook.net/signals/config/999149477285959?v=2.9.65&amp;r=stable">
#   </script>
#   <script async="" src="https://connect.facebook.net/en_US/fbevents.js">
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-PG637SH">
#   </script>
#   <script>
#    (function(h,o,t,j,a,r){        h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};        h._hjSettings={hjid:2942097,hjsv:6};        a=o.getElementsByTagName('head')[0];        r=o.createElement('script');r.async=1;        r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;        a.appendChild(r);    })(window,document,'https://static.hotjar.com/c/hotjar-','.js?sv=');
#   </script>
#   <script async="" src="https://static.hotjar.com/c/hotjar-2942097.js?sv=6">
#   </script>
#   <script defer="" src="https://cdn.leadster.com.br/neurolead/neurolead.min.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" src="https://script.hotjar.com/modules.575e0da598e3619bac00.js">
#   </script>
#   <style type="text/css">
#    iframe#_hjRemoteVarsFrame {display: none !important; width: 1px !important; height: 1px !important; opacity: 0 !important; pointer-events: none !important;}
#   </style>
#   <meta content="" http-equiv="origin-trial"/>
#   <style type="text/css">
#    /* Icons */
#
# @font-face {
#     font-family: neurolead;
#     src: url("data:font/woff;base64,...");
# }
#
# @font-face {
#   font-family: 'Open Sans Regular';
#   font-style: normal;
#   font-weight: 400;
#   src: local('Open Sans Regular'), local('OpenSans-Regular');
# }
#
# .nld-icon {
#     font-family: neurolead!important;
# }
#
# /* Animations */
#
# @keyframes nld-fade-in {
#     from {
#         opacity: 0;
#     }
#     to {
#         opacity: 1;
#     }
# }
#
# @keyframes nld-pop-in {
#     from {
#         opacity: 0;
#         transform: scale(0, 0);
#     }
#     to {
#         opacity: 1;
#         transform: scale(1, 1);
#     }
# }
#
# @keyframes nld-super-pop-in {
#     0% {
#         opacity: 0;
#         transform: scale(0, 0);
#     }
#     30% {
#         opacity: 1;
#         background-color: white;
#         transform: scale(1.5, 1.5);
#     }
#     80% {
#         transform: scale(1, 1);
#     }
#     100% {
#         opacity: 1;
#         transform: scale(1, 1);
#     }
# }
#
# @keyframes nld-pop-in-middle {
#     from {
#         opacity: 0;
#         transform: translateY(-50%) scale(0, 0);
#     }
#     to {
#         opacity: 1;
#         transform: translateY(-50%) scale(1, 1);
#     }
# }
#
# @keyframes nld-pop-out {
#     from {
#         opacity: 1;
#         transform: scale(1, 1);
#     }
#     to {
#         opacity: 0;
#         transform: scale(0, 0);
#     }
# }
#
# @keyframes nld-slide-in {
#     from {
#         display: block;
#         opacity: 0;
#         transform: translate(0, 100px);
#     }
#     to {
#         opacity: 1;
#         transform: translate(0, 0);
#     }
# }
#
# @keyframes nld-slide-out {
#     from {
#         opacity: 1;
#         transform: translate(0, 0);
#     }
#     to {
#         display: none;
#         opacity: 0;
#         transform: translate(0, 100px);
#     }
# }
#
# @keyframes nld-slide-out-up {
#     from {
#         opacity: 1;
#         transform: translate(0, 0);
#     }
#     to {
#         display: none;
#         opacity: 0;
#         height: 0;
#         overflow: hidden;
#         transform: translate(0, -100px);
#     }
# }
#
# @keyframes nld-blink {
#     50% {
#         opacity: 1;
#         transform: scale(0.5);
#     }
# }
#
# /* Elements */
#
# .nld-chatbot * {
#     position: initial;
# }
#
# .nld-chatbot {
#     color: inherit;
#     font: inherit;
#     font-family: "Helvetica Neue", "Neue Helvetica W01", Helvetica, Arial, -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, "Apple Color Emoji", "Segoe UI Emoji", "Segoe UI Symbol", sans-serif;
#     box-sizing: content-box;
# }
#
# .nld-chatbot * {
#     font: inherit!important;
#     color: inherit;
#     margin: initial;
#     box-sizing: content-box!important;
# }
#
# .nld-chatbot b {
#     font-weight: bold!important;
# }
#
# .nld-chatbot i {
#     font-style: italic!important;
# }
#
# .nld-chatbot strong {
#     display: initial !important;
#     font-weight: bold !important;
# }
#
# .nld-chatbot p {
#     color: #555 !important;
# }
#
# .nld-chatbot {
#     all: initial;
#     font-size: initial;
#
#     position: absolute;
#     z-index: 99999999;
#
#     top: 0;
#     left: 0;
# }
#
# .nld-chatbot>.nld-avatar {
#     /* Form */
#     width: 60px;
#     height: 60px;
#     border-radius: 30px!important;
#
#     /* Position */
#     display: inline-block;
#     position: fixed;
#     z-index: 32767;
#
#     bottom: 24px;
#     right: 18px;
#
#     vertical-align: middle;
#
#     /* Looks */
#     background-size: cover;
#     box-shadow: 0 0 12px 0 rgba(0, 0, 0, 0.15);
#
#     /* Typography */
#     font-size: 16px!important;
# }
#
# .nld-chatbot.nld-moving>.nld-avatar {
#     bottom: 12px;
#     right: 24px;
# }
#
# .nld-chatbot>.nld-avatar:hover {
#     box-shadow: 0 0 12px 0 rgba(0, 0, 0, 0.3);
#     cursor: pointer;
# }
#
# .nld-chatbot .nld-avatar::after {
#     content: "";
#
#     /* Form */
#     width: 15px;
#     height: 15px;
#     border-radius: 9px !important;
#
#     /* Position */
#     position: absolute;
#     bottom: 0;
#     right: 0;
#
#     /* Looks */
#     background-color: #2ecc71;
#
#     animation: nld-super-pop-in 0.5s cubic-bezier(0,.35,.28,.9) forwards;
#     animation-delay: 1s;
#
#     transform: scale(0, 0);
# }
#
# .nld-chatbot .nld-clear {
#     clear: both;
# }
#
# .nld-chatbot .nld-invite-message-container {
#     float: right;
#     max-width: 305px;
#     margin-right: 8px;
#     margin-top: 0;
#
#     display: flex;
#     align-items: center;
# }
#
# .nld-chatbot .nld-chatbot-invite-container {
#     right: 72px;
#
#     top: 50%;
#     transform: translateY(-50%);
#
#     width: 305px;
#
#     position: absolute;
# }
#
# .nld-chatbot .nld-chatbot-invite-message {
#     position: relative;
#     float: right;
#
#     border-radius: 8px!important;
#     padding: 9px;
#     padding-left: 17px;
#     box-shadow: 0 0 12px 0 rgba(0, 0, 0, 0.25);
#     border: 1px solid #d6d6d6;
#     color: #555 !important;
#     background: white;
#     line-height: 1.5em!important;
#     font-family: "Helvetica Neue", "Neue Helvetica W01", Helvetica, Arial, -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, "Apple Color Emoji", "Segoe UI Emoji", "Segoe UI Symbol", sans-serif!important;
#     font-size: 16px!important;
# }
#
# .nld-chatbot .nld-invite-message-text {
#     font-family: "Helvetica Neue", "Neue Helvetica W01", Helvetica, Arial, -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, "Apple Color Emoji", "Segoe UI Emoji", "Segoe UI Symbol", sans-serif !important;
# }
#
# .nld-chatbot .nld-invite-message-text strong {
#     font-weight: bold !important
# }
#
# .nld-chatbot .nld-invite-message-text em {
#     font-style: italic !important
# }
#
# .nld-chatbot .nld-invite-message-text p {
#     margin-bottom: 0 !important;
# }
#
# .nld-chatbot .nld-chatbot-invite-message::after {
#     content: "";
#
#     /* Form */
#     width: 16px;
#     height: 32px;
#
#     /* Position */
#     position: absolute;
#     top: 50%;
#     margin-top: -16px;
#     right: -16px;
#
#     /* Looks */
#     background-image: url(data:image/png;base64,...);
#     background-size: 32px 32px;
# }
#
# .nld-chatbot .nld-conversation {
#     /* Form */
#     width: 420px;
#     max-height: 370px;
#     min-height: 300px;
#     height: calc(100vh - 72px);
#     border-radius: 12px!important;
#
#     /* Position */
#     z-index: 32767;
#     position: fixed;
#     bottom: 48px;
#     right: 24px;
#
#     /* Looks */
#     background: white;
#     box-shadow: 0 0 24px 0 rgba(0, 0, 0, 0.15);
# }
#
# .nld-chatbot .nld-bg {
#     position: absolute;
#
#     top: 0; left: 0;
#     bottom: 0; right: 0;
#     border-radius: 8px!important;
#
#     background: white;
# }
#
# .nld-chatbot .nld-conversation.nld-full {
#     max-height: 550px;
#     transition: max-height 0.5s ease-in-out;
# }
#
# .nld-chatbot .nld-conversation>.nld-ctx {
#     position: absolute;
#     top: 0px;
#     bottom: 0px;
#     left: 0;
#     right:0;
#
#     border-radius: 8px!important;
# }
#
# .nld-chatbot .nld-typing-indicator {
#     width: 54px;
#
#     display: inline-block;
#     vertical-align: middle;
# }
#
# .nld-chatbot .nld-typing-indicator>span {
#     width: 12px;
#     height: 12px;
#     border-radius: 6px!important;
#
#     margin-right: 6px;
#
#     float: left;
#
#     opacity: 0.5;
#
#     background: #2ecc71;
# }
#
# .nld-chatbot .nld-typing-indicator>span:nth-child(1) {
#     animation: 1s nld-blink infinite .1666s;
# }
#
# .nld-chatbot .nld-typing-indicator>span:nth-child(2) {
#     animation: 1s nld-blink infinite .3332s;
# }
#
# .nld-chatbot .nld-typing-indicator>span:nth-child(3) {
#     animation: 1s nld-blink infinite .5s;
# }
#
# /* States */
#
# .nld-nodisplay {
#     display: none !important;
# }
#
# .nld-chatbot .nld-hidden {
#     /* Animations */
#     animation-name: nld-pop-out;
#     animation-duration: 0.3s;
#     animation-fill-mode: forwards;
# }
#
# .nld-chatbot .nld-shown {
#     /* Animations */
#     animation-name: nld-pop-in;
#     animation-duration: 0.3s;
#     animation-fill-mode: forwards;
# }
#
# .nld-chatbot .nld-shown-middle {
#     /* Animations */
#     animation-name: nld-pop-in-middle;
#     animation-duration: 0.5s;
#     animation-fill-mode: forwards;
# }
#
# .nld-chatbot .nld-hidden-slide {
#     /* Animations */
#     animation-name: nld-slide-out;
#     animation-duration: 0.5s;
#     animation-fill-mode: forwards;
# }
#
# .nld-chatbot .nld-hidden-slideup {
#     /* Animations */
#     animation-name: nld-slide-out-up;
#     animation-duration: 0.5s;
#     animation-fill-mode: forwards;
# }
#
# .nld-chatbot .nld-shown-slide {
#     /* Animations */
#     animation-name: nld-slide-in;
#     animation-duration: 0.5s;
#     animation-fill-mode: forwards;
# }
#
# .nld-chatbot .nld-close {
#     position: absolute;
#     top: 23px;
#     right: 24px;
#
#     width: 25px;
#     height: 25px;
#
#     z-index: 9999999;
# }
#
# .nld-chatbot.nld-left .nld-chatbot-invite-message .nld-close {
#     top: -12px;
#     right: -12px;
#     left: auto;
#
#     background: #aaa;
#     border-radius: 13px!important;
# }
#
# .nld-chatbot .nld-chatbot-invite-message .nld-close {
#     top: -12px;
#     left: -12px;
#
#     background: #aaa;
#     border-radius: 13px!important;
# }
#
# .nld-chatbot .nld-close-white {
#     display: block;
# }
#
# .nld-chatbot .nld-close-black {
#     display: none;
# }
#
# .nld-chatbot .nld-close:hover {
#     cursor: pointer;
# }
#
# .nld-chatbot .nld-close>img {
#     all: inherit;
#     width: 25px;
#     top: 0;
#     left: 0;
# }
#
# /* Modifiers */
#
# /* Left */
#
# .nld-chatbot.nld-left>.nld-avatar {
#     left: 18px;
# }
#
# .nld-chatbot.nld-left .nld-chatbot-invite-container {
#     left: 72px;
# }
#
# .nld-chatbot.nld-left .nld-chatbot-invite-message {
#     float: left;
# }
#
# .nld-chatbot.nld-left .nld-conversation {
#     left: 24px;
# }
#
# .nld-chatbot.nld-left .nld-chatbot-invite-message::after {
#     left: -16px;
#     right: initial;
#     transform: scale(-1, 1);
# }
#
# /* Center */
#
# .nld-chatbot.nld-center>.nld-avatar {
#     left: 50%;
#     margin-left: -30px;
# }
#
# .nld-chatbot.nld-center .nld-chatbot-invite-container {
#     left: 72px;
# }
#
# .nld-chatbot.nld-center .nld-chatbot-invite-message {
#     float: left;
# }
#
# .nld-chatbot.nld-center .nld-conversation {
#     left: calc(100vw/2 - 360px);
#     width: 100vw;
#     max-width: 720px;
# }
#
# .nld-chatbot.nld-center .nld-chatbot-invite-message::after {
#     left: -16px;
#     right: initial;
#     transform: scale(-1, 1);
# }
#
# .nld-chatbot .nld-conversation-header {
#     width: 100%;
#     height: 100px;
#
#     border-radius: 8px 8px 0 0!important;
#
#     background-image: linear-gradient(to right, #bc002c, #ea083d);
# }
#
# .nld-chatbot .nld-mobile-brand {
#     position: absolute;
#
#     bottom: 0; left: 0;
#
#     width: 100%;
#     text-align: center;
#
#     margin-bottom: -28px;
# }
#
# .nld-chatbot .nld-mobile-brand .nld-logo {
#     width: 160px;
#     opacity: 0.5;
# }
#
# .nld-chatbot .nld-brand {
#     position: absolute;
#
#     display: inline-block;
#     width: 100%;
#
#     margin: 0;
#
#     text-align: center;
#
#     bottom: -1.70em;
# }
#
# .nld-chatbot .nld-brand a {
#     padding-top: 8px;
#     background: #eee;
#
#     margin-top: 1px;
#
#     box-shadow: 0 0 24px 0 rgba(0, 0, 0, 0.15);
#
#     border-radius: 0 0 6px 6px!important;
#
#     border: 1px solid #ddd;
#
#     display: inline-block !important;
# }
#
# .nld-chatbot .nld-brand a img {
#     padding: 0;
#     margin: 0;
#     vertical-align: baseline;
#     opacity: 0.7;
# }
#
# .nld-chatbot .nld-brand a img:hover {
#     opacity: 1;
# }
#
# .nld-chatbot img.nld-3rdparty-branding {
#     height: 58px;
#     width: auto !important;
#
#     margin: 0 auto;
#     padding-top: 6px;
#
#     display: none;
# }
#
# .nld-chatbot .nld-logo {
#     width: 200px;
# }
#
# .nld-infobar {
#     color: white;
#
#     border-radius: 8px 8px 0 0!important;
#
#     font-family: "Open Sans Regular",sans-serif !important;
#
#     height: 72px;
#
#     display: flex;
#     align-items: center;
# }
#
# .nld-chatbot .nld-infobar>.nld-avatar {
#     width: 50px;
#     height: 50px;
#     border-radius: 25px!important;
#
#     left: 12px;
#     top: 11px;
#
#     position: absolute;
#
#     background-size: cover;
# }
#
# .nld-chatbot .nld-infobar>.nld-avatar::after {
#     border: 2px solid #cf0237;
# }
#
# .nld-chatbot .nld-infobar .nld-info {
#     margin: 0;
#     margin-left: 68px;
# }
#
# .nld-chatbot .nld-info .nld-title {
#     font-size: 1em !important;
#     margin-bottom: 6px;
#     margin-top: -6px;
# }
#
# .nld-chatbot .nld-info .nld-subtitle {
#     font-size: 0.75em !important;
# }
#
# /* Conversational Form Implementation */
#
# .nld-chatbot .nld-ctx {
#     font-family: "Open Sans Regular",sans-serif !important;
# }
#
# /* Conversation container */
#
# .nld-chatbot .nld-ctx>div>.nld-container {
#     position: absolute;
#     top: 72px;
#     left: 0;
#     right:0;
#     bottom: 64px;
#
#     border-radius: 8px 8px 0 0!important;
#
#     background-color: white;
#
#     overflow: hidden;
# }
#
# .nld-chatbot .nld-container:focus-visible, .nld-chatbot .nld-group {
#     outline: none;
# }
#
# .nld-chatbot .nld-ctx>div>.nld-container.nld-full {
#     bottom: 0;
#     border-radius: 8px 8px 8px 8px!important;
# }
#
# .nld-chatbot .nld-ctx>div>.nld-overlay {
#     position: absolute;
#
#     top: 72px;
#     left: 0;
#     right: 0;
#
#     height: 36px;
#
#     background: white;
#
#     background: linear-gradient(to bottom, white, rgba(255,255,255,0));
#     background: -moz-linear-gradient(to bottom, white, rgba(255,255,255,0));
#     background: -webkit-linear-gradient(to bottom, white, rgba(255,255,255,0));
# }
#
# /* Bubbles */
#
# .nld-chatbot .nld-msg .nld-bubble {
#     padding: 16px 24px;
#     margin: 12px;
#     margin-bottom: 0;
#
#     background: #f0f0f0;
#
#     line-height: 1.5 !important;
#     font-size: 0.9em !important;
#
#     display: inline-block;
#
#     border-radius: 24px!important;
#
#     clear: both;
# }
#
# .nld-chatbot .nld-msg .nld-bubble img {
#     margin-top: 6px;
#     width: 100%;
# }
#
# .nld-chatbot .nld-msg .nld-bubble b {
#     font-weight: bold !important;
#     display: initial !important;
# }
#
# .nld-chatbot .nld-msg .nld-bubble a {
#     text-decoration: underline;
#     color: #07C;
# }
#
# /* Bubble left/right styles */
#
# .nld-chatbot .nld-ctx .nld-group.nld-right .nld-bubble {
#     background-image: linear-gradient(to right, #bc002c, #ea083d);
#
#     color: white;
# }
#
# .nld-chatbot .nld-ctx .nld-group.nld-left .nld-bubble {
#     color: black;
# }
#
# .nld-chatbot .nld-ctx .nld-group.nld-left .nld-bubble p {
#     color: #000 !important;
# }
#
# /* Middle Bubbles
#
#    .nld-ctx .nld-group.nld-right .nld-bubble {
#    border-radius: 8px 0 0 8px;
#    margin-top: 2px;
#    margin-bottom: 2px;
#    }
#
#    .nld-ctx .nld-group.nld-left .nld-bubble {
#    border-radius: 0 8px 8px 0;
#    margin-top: 2px;
#    margin-bottom: 2px;
#    }
#
#  */
#
# /* Bottom Bubbles
#
#    .nld-ctx .nld-group.nld-right .nld-msg:last-child .nld-bubble {
#    border-radius: 8px 0 8px 8px;
#    margin-top: 2px;
#    }
#
#    .nld-ctx .nld-group.nld-left .nld-msg:last-child .nld-bubble {
#    border-radius: 0 8px 8px 8px;
#    margin-top: 2px;
#    }
#
#  */
#
# .nld-chatbot .nld-ctx .nld-group.nld-right .nld-msg:last-child .nld-bubble {
#     margin-bottom: 6px;
# }
#
# .nld-chatbot .nld-ctx .nld-group.nld-left .nld-msg:last-child .nld-bubble {
#     margin-bottom: 6px;
# }
#
# /* Top Bubbles
#
#    .nld-ctx .nld-group.nld-right .nld-msg:first-child .nld-bubble {
#    border-radius: 8px 8px 0 8px;
#    margin-top: 0;
#    }
#
#    .nld-ctx .nld-group.nld-left .nld-msg:first-child .nld-bubble {
#    border-radius: 8px 8px 8px 0;
#    margin-top: 0;
#    }
#
#  */
#
# .nld-chatbot .nld-ctx .nld-group.nld-right .nld-msg:first-child .nld-bubble {
#     margin-top: 0;
# }
#
# .nld-chatbot .nld-ctx .nld-group.nld-left .nld-msg:first-child .nld-bubble {
#     margin-top: 0;
# }
#
# /* Message groups (blocks of speech) */
#
# .nld-chatbot .nld-ctx .nld-group {
#     display: block;
#
#     clear: both;
#
#     max-width: 80%;
#
#     margin: 6px;
# }
#
# .nld-chatbot .nld-ctx .nld-group.nld-full {
#     display: block;
#
#     clear: both;
#
#     width: 100%;
#     max-width: calc(100% - 48px);
#
#     margin-bottom: 16px;
#     margin-top: 16px;
# }
#
# .nld-chatbot .nld-ctx .nld-group.nld-nomargin {
#     position: relative;
#     display: block;
#
#     clear: both;
#
#     width: calc(100% + 6px);
#     max-width: calc(100% + 6px);
#
#     right: -6px;
#
#     margin: 0;
#     padding: 0;
# }
#
# /* Left/Right message groups */
#
# .nld-chatbot .nld-ctx .nld-group.nld-left {
#     float: left;
#     text-align: left;
# }
#
# .nld-chatbot .nld-ctx .nld-group.nld-right {
#     float: right;
#     text-align: right;
# }
#
# /*
#  * Message containers (inside groups). Used to allow for custom
#  * content like avatars side by side inside message groups.
#  */
#
# .nld-chatbot .nld-ctx .nld-group.nld-left .nld-container {
#     max-width: calc(100% - 40px);
#     min-width: 200px;
# }
#
# .nld-chatbot .nld-ctx .nld-group.nld-full .nld-container {
#     max-width: 21em;
#     width: 100%;
# }
#
# .nld-chatbot .nld-ctx .nld-group.nld-left .nld-container {
#     float: left;
# }
#
# .nld-chatbot .nld-ctx .nld-group.nld-right .nld-container {
#     float: right;
# }
#
# /* Message group avatar */
#
# .nld-chatbot .nld-group.nld-left .nld-msg-avatar {
#     float: left;
#     margin-left: 8px;
# }
#
# .nld-chatbot .nld-group.nld-right .nld-msg-avatar {
#     float: right;
#     margin-right: 8px;
# }
#
# .nld-chatbot .nld-msg-avatar>.nld-img {
#     width: 32px;
#     height: 32px;
#     border-radius: 16px!important;
#
#     object-fit: cover;
# }
#
# /* Timestamps */
#
# .nld-chatbot .nld-timestamp {
#     display: block;
#     color: #979797;
#     font-size: 0.75em!important;
#
#     margin: 6px 0 6px 6px;
# }
#
# .nld-chatbot .nld-group.nld-left .nld-timestamp {
#     float: right;
# }
#
# .nld-chatbot .nld-group.nld-right .nld-timestamp {
#     float: right;
#     color: #f5f5f5;
# }
#
# /* Text Input */
#
# .nld-chatbot .nld-input {
#     position: absolute;
#
#     left: 0; right: 0;
#
#     bottom: 16px;
#     height: 48px;
#
#     border-radius: 0 0 8px 8px!important;
# }
#
# .nld-chatbot .nld-input.nld-plain {
#     box-shadow: none;
# }
#
# .nld-chatbot .nld-input.nld-hide {
#     height: 0;
# }
#
# .nld-chatbot .nld-input.nld-hide .nld-submit{
#     display: none;
# }
#
# .nld-chatbot .nld-input>.nld-submit {
#     box-sizing: content-box;
#
#     background-image: url('data:image/png;base64,...');
#     background-size: 30px 30px;
#
#     width: 30px;
#     height: 30px;
#
#     display: inline-block;
#     position: absolute;
#     right: 24px;
#     bottom: 6px;
#
#     border-radius: 16px!important;
#     border: 1px solid;
# }
#
# .nld-chatbot .nld-input>.nld-submit:hover {
#     cursor: pointer;
# }
#
# .nld-chatbot .nld-input>.nld-submit.nld-only {
#     left: 50%;
#     transform: translateX(-50%);
#
#     width: auto;
#     text-align: center;
#     line-height: 30px !important;
#     text-transform: uppercase;
#
#     background: transparent !important;
# }
#
# .nld-chatbot .nld-input>input {
#     width: calc(100% - 64px) !important;
#     height: 46px !important;
#
#     background: white;
#     color: black!important;
#
#     border-radius: 32px!important;
#     outline: none;
#     border: 2px solid #eee;
#     margin: 0 14px;
#
#     padding: 0 16px !important;
#     padding-bottom: 2px;
#
#     font-size: 1em!important;
#
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     appearance: none;
# }
#
# /* iOS Fix */
# input[type=text] {
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     appearance: none;
#
# }
# /* Select Box */
#
# .nld-chatbot .nld-input select {
#     width: calc(100% - 64px) !important;
#     height: 46px !important;
#
#     background: white;
#     color: black!important;
#     position: relative;
#
#     border-radius: 32px!important;
#     outline: none;
#     border: 2px solid #eee;
#     margin: 0 14px;
#
#     padding: 0 16px !important;
#     padding-bottom: 2px;
#
#     font-size: 1em!important;
#
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     appearance: none;
# }
#
# .nld-chatbot .nld-input > .custom-select {
#     position: relative;
# }
#
# .nld-chatbot .nld-input > .custom-select:after {
#     content: "▼";
#     position: absolute;
#     color: #4c4c4c;
#     top: 4px;
#     right: 60px;
#     padding: 12px 7px;
#     pointer-events: none;
# }
#
# .nld-chatbot .nld-input>select::-ms-expand {
#     display: none;
# }
#
# /* Selectors (Single/Multi option) */
#
# .nld-chatbot .nld-sel {
#     padding: 24px 0;
#     margin: 0;
#     right: 6px;
#     position: relative;
# }
#
# .nld-chatbot .nld-sel>.nld-opt {
#     padding: 12px 24px;
#     border-radius: 24px!important;
#     display: inline-block;
#     cursor: pointer;
#     color: white;
#     background-image: linear-gradient(to right, #bc002c, #ea083d);
#     box-shadow: 0 3px 6px 0 rgba(0, 0, 0, 0.15);
#     margin: 3px;
#     text-align: center;
# }
#
# .nld-chatbot .nld-sel>.nld-opt:hover {
#     box-shadow: 0 3px 12px 0 rgba(0, 0, 0, 0.3);
# }
#
# .nld-chatbot .nld-sel.nld-multi {
#     padding: 12px 0;
# }
#
# .nld-chatbot .nld-sel.nld-multi>.nld-opt.nld-selected {
#     background-image: linear-gradient(to right, #f31448, #ff6084);
# }
#
# .nld-chatbot .nld-sel.nld-multi>.nld-opt {
#     background: transparent;
#     border: 1px solid #f31448;
#     color: #222;
# }
#
# .nld-chatbot .nld-secondary {
#     padding: 4px 8px;
#     background: transparent !important;
#     color: #0592ff !important;
#     box-shadow: none !important;
#     border: none!important;
#     font-size: 12px!important;
#     text-decoration: underline!important;
# }
#
# .nld-chatbot .nld-secondary:hover {
#     box-shadow: none !important;
#     color: #0277d1!important;
# }
#
# .nld-chatbot .nld-secondary.nld-selected {
#     background-image: none!important;
# }
#
# /* Message-Selector */
#
# .nld-chatbot .nld-sel.nld-messages {
#     padding: 0;
#     margin: 0;
#
#     padding-top: 12px;
# }
#
# .nld-chatbot .nld-sel.nld-messages>.nld-opt {
#     margin: 6px 6px 0 0;
#     padding: 12px 16px;
#
#     border-radius: 24px!important;
#
#     display: inline-block;
#
#     cursor: pointer;
#
#     color: white;
#
#     background-image: linear-gradient(to right, #bc002c, #ea083d);
#     box-shadow: 0 3px 6px 0 rgba(0, 0, 0, 0.15);
# }
#
# .nld-chatbot .nld-sel.nld-messages>.nld-opt:hover {
#     background-image: linear-gradient(to right, #bc002c, #ea083d);
#     box-shadow: 0 3px 12px 0 rgba(0, 0, 0, 0.3);
# }
#
# .nld-chatbot .nld-sel.nld-messages>.nld-opt.nld-selected {
#     background-image: linear-gradient(to right, #f31448, #ff6084);
# }
#
# /* Time Selector */
#
# .nld-chatbot .nld-sel.nld-time {
#     margin-right: 16px;
#
#     border-radius: 8px!important;
#
#     border: 1px solid #bc002c;
#
#     overflow: hidden;
# }
#
# .nld-chatbot .nld-timedisplay {
#     background-image: linear-gradient(to right, #bc002c, #ea083d);
#
#     font-size: 3em!important;
#     color: rgba(255, 255, 255, 0.8);
#
#     padding: 6px 24px;
# }
#
# .nld-chatbot .nld-timepicker {
#     background: white;
#
#     padding: 6px;
# }
#
# .nld-chatbot .nld-timepicker .nld-clock {
#     width: 14em;
#     height: 14em;
#     border-radius: 7em!important;
#
#     background: #eee;
#
#     position: relative;
# }
#
# .nld-chatbot .nld-clock .nld-num-container {
#     width: 11em;
#     height: 11em;
#
#     top: 1.5em;
#     left: 1.5em;
#
#     position: relative;
# }
#
# .nld-chatbot .nld-clock .nld-pivot {
#     box-sizing: content-box;
#
#     position: absolute;
#
#     top: 50%;
#     left: 50%;
#
#     margin-top: -0.25em;
#     margin-left: -0.25em;
#
#     width: 0.5em;
#     height: 0.5em;
#
#     border-radius: 0.5em!important;
#
#     border: 2px solid #ea083d;
# }
#
# .nld-chatbot .nld-clock .nld-pointer {
#     position: absolute;
#
#     top: 0.25em;
#     left: 0.5em;
#
#     margin-top: -1px;
#
#     width: 4.55em;
#     height: 2px;
#
#     transform-origin: -0.25em 1px;
#
#     background: #ea083d;
# }
#
# .nld-chatbot .nld-clock .nld-clock-num {
#     position: absolute;
#
#     width: 2em;
#     height: 2em;
#
#     margin-top: -1em;
#     margin-left: -1em;
#
#     line-height: 2em !important;
#
#     text-align: center;
#     vertical-align: middle;
#
#     cursor: pointer;
#
#     color: #888;
#
#     border-radius: 1em!important;
# }
#
# .nld-chatbot .nld-clock .nld-clock-num.nld-disabled {
#     color: #ddd;
# }
#
# .nld-chatbot .nld-clock .nld-clock-num:hover {
#     color: black;
# }
#
# .nld-chatbot .nld-clock .nld-clock-num.nld-selected {
#     color: white;
#     background: #ea083d;
# }
#
# .nld-chatbot .nld-timedisplay .nld-hours {
#     display: inline-block;
#
#     cursor: pointer;
# }
#
# .nld-chatbot .nld-timedisplay .nld-minutes {
#     display: inline-block;
#
#     cursor: pointer;
# }
#
# .nld-chatbot .nld-timedisplay .nld-sep {
#     display: inline-block;
#
#     color: #eee;
# }
#
# .nld-chatbot .nld-hours.nld-selected {
#     color: white;
#
#     border-bottom: 3px solid white;
# }
#
# .nld-chatbot .nld-minutes.nld-selected {
#     color: white;
#
#     border-bottom: 3px solid white;
# }
#
# .nld-chatbot .nld-timedisplay .nld-period {
#     float: right;
#     font-size: 0.33em!important;
#     margin-top: 0.8em;
#     margin-left: 1em;
# }
#
# .nld-chatbot .nld-period .nld-day {
#     cursor: pointer;
# }
#
# .nld-chatbot .nld-period .nld-night {
#     cursor: pointer;
# }
#
# .nld-chatbot .nld-period .nld-day.nld-selected {
#     color: white;
#     font-weight: bold !important;
# }
#
# .nld-chatbot .nld-period .nld-night.nld-selected {
#     color: white;
#     font-weight: bold !important;
# }
#
# /* Date selector */
#
# .nld-chatbot .nld-sel.nld-date {
#     padding: 0;
#     padding-bottom: 12px;
#
#     right: 6px;
#
#     position: relative;
# }
#
# .nld-chatbot .nld-cal {
#     position: relative;
#
#     min-width: 18em;
#     width: 100%;
#     height: 16em;
#
#     background: white;
#
#     border-radius: 8px!important;
#
#     border: 1px solid #cf0237;
#
#     color: #444;
#
#     font-size: 0.8em!important;
#
#     overflow: hidden;
# }
#
# .nld-chatbot .nld-cal>.nld-row {
#     width: 100%;
#     height: 2em;
#
#     text-align: center;
# }
#
# .nld-chatbot .nld-row.nld-title {
#     font-weight: bold!important;
#
#     color: white;
#
#     background-image: linear-gradient(to right, #bc002c, #ea083d);
# }
#
# .nld-chatbot .nld-row.nld-header {
#     font-weight: bold!important;
#     color: white;
#     background-image: linear-gradient(to right, #bc002c, #ea083d);
#     border-radius: 6px 6px 0 0!important;
#     vertical-align: middle;
# }
#
# .nld-chatbot .nld-row.nld-header>.nld-header {
#     padding-top: 0.5em;
# }
#
# .nld-chatbot .nld-cal .nld-prev {
#     float: left;
#     padding-left: 12px;
#
#     cursor: pointer;
#
#     -moz-transform: scaleX(-1);
#     -o-transform: scaleX(-1);
#     -webkit-transform: scaleX(-1);
#     transform: scaleX(-1);
#     filter: FlipH;
#     -ms-filter: "FlipH";
#
#     width: 16px;
#     height: 16px;
#
#     background-image: url('...');
#     background-size: 16px;
#
#     background-repeat: no-repeat;
# }
#
# .nld-chatbot .nld-cal .nld-next {
#     float: right;
#     margin-right: 12px;
#
#     cursor: pointer;
#
#     width: 16px;
#     height: 16px;
#
#     background-image: url('...');
#     background-size: 16px;
# }
#
# .nld-chatbot .nld-next.nld-full,.nld-chatbot .nld-prev.nld-full {
#     background-image: url('...');
# }
#
# .nld-chatbot .nld-cal .nld-cell {
#     box-sizing: content-box;
#     display: inline-block;
#
#     width: 14.2857%;
#     height: 50%;
#
#     padding: 0.5em 0;
#
#     text-align: center;
#
#     cursor: pointer;
#
#     user-select: none;
#
#     position: relative;
# }
#
# .nld-chatbot .nld-cell.nld-this-month {
# }
#
# .nld-chatbot .nld-cell.nld-disabled {
#     background-color: #eee;
#     cursor: not-allowed;
# }
#
# .nld-chatbot .nld-cell.nld-next-month {
#     color: #bbb;
# }
#
# .nld-chatbot .nld-cell.nld-prev-month {
#     color: #999;
# }
#
# .nld-chatbot .nld-cell.nld-today {
#     font-weight: bold!important;
#     color: black;
# }
#
# .nld-chatbot .nld-cell.nld-selected {
#     font-weight: bold!important;
#     color: black;
# }
#
# .nld-chatbot .nld-cell.nld-selected::after {
#     box-sizing: content-box;
#
#     width: calc(100% - 8px);
#     height: calc(100% - 6px);
#
#     border-radius: 6px!important;
#
#     border: 1px solid #cf0237;
#
#     opacity: 0.5;
#
#     position: absolute;
#
#     top: 3px; left: 3px;
#
#     content: "";
# }
#
# /* Carousel */
#
# /* Hide scrollbar */
# .glider {
#     margin-bottom: -50px!important;
#     padding-bottom: 50px!important;
# }
# .nld-chatbot .nld-carousel {
#     overflow: hidden;
# }
#
# .nld-chatbot .nld-carousel .nld-prev, .nld-chatbot .nld-carousel .nld-next {
#     position: absolute;
#
#     width: 2em; height: 2em;
#
#     top: 25%; margin-top: -1em;
#     left: 0;
#     margin: 0.25em;
#
#     z-index: 1;
#
#     border: 1px solid #ddd;
#     background: white;
#     border-radius: 0.25em!important;
#
#     color: #888;
#
#     cursor: pointer;
#
#     user-select: none;
# }
#
# .nld-chatbot .nld-carousel .nld-next {
#     right: 0;
#     left: auto;
# }
#
# .nld-chatbot .nld-carousel .nld-card {
#     background: white;
#
#     border: 1px solid #ddd;
#
#     margin: 0.25em 0.5em;
#     margin-bottom: 1em;
#     padding: 0;
#
#     border-radius: 0.5em!important;
#
#     overflow: hidden;
# }
#
# .nld-chatbot .nld-carousel .nld-card .nld-card-body {
#     min-height: 12em;
#
#     text-align: left;
#
#     background-size: cover;
#
#     color: white;
# }
#
# .nld-chatbot .nld-carousel .nld-card .nld-card-title {
#     padding: 0.5em;
#     margin: 0;
#
#     text-align: left;
# }
#
# .nld-chatbot .nld-carousel .nld-card .nld-sel {
#     padding: 0;
#     right: 0;
#
#     margin: 6px;
#     margin-bottom: 12px;
# }
#
# .nld-chatbot .nld-carousel .nld-card .nld-opt {
#     display: block;
#     margin: 6px;
# }
#
# /* Scrollbar */
#
# .nld-chatbot .nld-scrollable {
#     width: calc(100% - 6px);
#     height: 100%;
#
#     box-sizing: content-box;
#
#     overflow-y: scroll;
#
#     margin-right: -50px;
#     padding-right: 50px;
# }
#
# .nld-chatbot .nld-scrollbar {
#     position: absolute;
#     top: 0;
#     right: 0;
#
#     width: 6px;
#     height: 100%;
# }
#
# .nld-chatbot .nld-handle {
#     width: 100%;
#
#     position: absolute;
#
#     border-radius: 3px!important;
#
#     background: #ea083d;
#
#     opacity: 0.8;
# }
#
# .nld-chatbot .nld-whitespace {
#     width: 100%;
#     height: 1em;
#     background: none;
# }
#
# .nld-chatbot .nld-input .nld-tooltip-error {
#     position: absolute;
#     display: flex;
#     background-color: #CB2134;
#     color: #FFF;
#     margin: 0px 20px;
#     width: calc(100% - 64px) !important;
#     border-radius: 8px;
#     padding: 5px 10px;
#     font-size: 14px !important;
#     transform: translateY(-135%);
#     box-shadow: 0 1px 8px rgb(0 0 0 / 50%);
# }
#
# .nld-chatbot .nld-input .nld-tooltip-error:after {
#     content: '';
#     position: absolute;
#     display: block;
#     width: 14px;
#     height: 14px;
#     transform-origin: 50% 50%;
#     transform: rotate(45deg) translateX(-50%);
#     background-color: inherit;
#     z-index: -10;
#     left: 20px;
#     top: auto;
#     bottom: -10px;
#     border-radius: 2px;
# }
#
# .nld-chatbot .nld-multi .nld-tooltip-error {
#     position: absolute;
#     display: flex;
#     background-color: #CB2134;
#     color: #FFF;
#     border-radius: 8px;
#     padding: 5px 10px;
#     right: 0;
#     font-size: 14px !important;
#     transform: translateY(-135%);
#     box-shadow: 0 1px 8px rgb(0 0 0 / 50%);
# }
#
# .nld-chatbot .nld-multi .nld-tooltip-error:after {
#     content: '';
#     position: absolute;
#     display: block;
#     width: 14px;
#     height: 14px;
#     transform-origin: 50% 50%;
#     transform: rotate(45deg) translateX(-50%);
#     background-color: inherit;
#     z-index: -10;
#     right: 20px;
#     top: auto;
#     bottom: -10px;
#     border-radius: 2px;
# }
#
# .nld-chatbot .nld-bubble a.whatsapp-link {
#     text-decoration: none;
# }
#
# .nld-chatbot .nld-bubble a.whatsapp-link > div {
#     background: #455a64;
#     color: white;
#     padding: 1em;
#     border-radius: 0.5em;
#     box-shadow: 0 6px 12px rgba(0,0,0,0.2);
#     font-weight: bold;
#     margin-top: 1em;
# }
#
# .nld-chatbot .nld-bubble a.whatsapp-link > div > img {
#     width: 2em;
#     height: 2em;
#     margin-top: -0.25em;
#     margin-right: 0.25em;
#     float: left;
# }
#
#
# .nld-chatbot .nld-bubble a.reset-chat {
#     color: #FFFFFF;
#     font-weight: bold !important;
# }
#
# .nld-chatbot .nld-bubble a.reset-chat > img {
#     margin-left: 10px;
#     vertical-align: -5px;
#     margin-top: 0 !important;
#     width: inherit !important;
# }
#
#
# /* Media Queries */
# @media only screen and (max-device-width: 720px) {
#     .nld-chatbot.nld-center .nld-conversation {
#         width: auto;
#         height: auto;
#         max-height: none;
#         min-height: none;
#
#         position: fixed;
#
#         left: 0;
#         right: 0;
#         top: 0;
#         bottom: 0;
#
#         z-index: 32767;
#     }
#
# }
#
# @media only screen and (max-width: 720px) {
#     .nld-chatbot.nld-center>.nld-avatar {
#         left: 0!important;
#         margin-left: 0!important;
#     }
# }
#
# @media only screen and (max-device-width: 720px) {
#     .nld-chatbot .nld-conversation {
#         border-radius: 0!important;
#     }
#
#     .nld-chatbot .nld-conversation-header {
#         border-radius: 0!important;
#     }
#
#     .nld-chatbot .nld-avatar {
#         bottom: 48px;
#     }
#
#     .nld-chatbot .nld-conversation,
#     .nld-chatbot.nld-left .nld-conversation,
#     .nld-chatbot.nld-right .nld-conversation {
#         width: auto;
#         height: auto;
#         max-height: none !important;
#         min-height: none !important;
#
#         position: fixed;
#
#         left: 0;
#         right: 0;
#         top: 0;
#         bottom: 0;
#
#         z-index: 32767;
#     }
#
#     .nld-chatbot .nld-invite-message-container {
#         max-width: 200px;
#         max-width: calc(100vw - 138px);
#     }
#
#     .nld-chatbot .nld-invite-message-container.nld-notification .nld-invite-message-text {
#         min-width: 0!important;
#     }
#
#     .nld-chatbot .nld-invite-message-container.nld-notification .nld-footer.nld-verified {
#         display: none!important;
#     }
#
#     .nld-chatbot .nld-ctx>div>.nld-container, .nld-ctx>div>.nld-overlay {
#         top: 72px;
#         border-radius: 0 !important;
#     }
#
#     .nld-chatbot .nld-ctx>div>.nld-container {
#         bottom: 76px;
#     }
#
#     .nld-chatbot .nld-ctx>div>.nld-container.nld-full {
#         bottom: 18px;
#     }
#
#     .nld-chatbot .nld-close-white {
#         display: block;
#     }
#
#     .nld-chatbot .nld-close-black {
#         display: none;
#     }
#
#     .nld-chatbot .nld-input>input {
#         font-size: 1.1em!important;
#     }
#
#     .nld-chatbot .nld-input {
#         bottom: 28px;
#     }
#
#     .nld-chatbot .nld-msg .nld-bubble {
#         font-size: 1em!important;
#     }
# }
#
# /* Waiting Spinnner */
#
# .nld-chatbot .nld-input .nld-spinner {
#     position: relative;
#     width: 2em; height: 2em;
#
#     top: 50%;
#     left: 50%;
#     margin-left: -1em;
#     margin-top: -1em;
# }
#
# .nld-chatbot .nld-input .nld-spinner div {
#     position: absolute;
#     border-width: 0.25em;
#     border-style: solid;
#     border-color: inherit;
#     margin-top: -0.25em;
#     border-radius: 50%!important;
#     animation: nld-spinner 1.6s cubic-bezier(0,.35,.28,.9) infinite;
# }
#
# .nld-chatbot .nld-input .nld-spinner div:nth-child(2) {
#     animation-delay: -0.64s;
# }
#
# @keyframes nld-spinner {
#     0% { top: 50%; left: 50%; width: 0; height: 0; opacity: 1; }
#     80% {  top: 0; left: 0; width: 100%; height: 100%; opacity: 0; }
#     100% { opacity: 0; top: 50%; left: 50%; width: 0; height: 0; }
# }
#
# /* Social Proof Icon */
# .nld-chatbot .nld-sp-icon {
#     margin: -4px;
#
#     min-width: 64px;
#     height: 64px;
#     border-radius: 50%!important;
#     background-size: 0%;
# }
#
# .nld-chatbot .nld-sp-icon div:not(:nth-child(3)) {
#     position: absolute;
#
#     background: inherit;
#     border-radius: 50%!important;
#
#     animation: nld-pulse 2.6s cubic-bezier(0,.35,.28,.9) infinite;
# }
#
# .nld-chatbot .nld-sp-icon div:nth-child(2) {
#     animation-delay: -0.64s;
# }
#
# .nld-chatbot .nld-sp-icon .nld-img {
#     position: absolute;
#     width: 100%;
#     height: 100%;
#     border-radius: 50%!important;
#     background-size: 100%;
# }
#
# .nld-chatbot .nld-sp-icon.nld-right {
#     margin-right: 0;
#     margin-left: 12px;
#
#     animation: nld-slide-in 0.8s cubic-bezier(0,.35,.28,.9) forwards;
# }
#
# .nld-chatbot .nld-sp-icon.nld-left {
#     margin-left: 0;
#     margin-right: 12px;
#
#     animation: nld-slide-in 0.4s cubic-bezier(0,.35,.28,.9) forwards;
# }
#
# .nld-chatbot .nld-footer {
#     display: none;
# }
#
# .nld-chatbot .nld-footer.nld-verified::before {
#     position: absolute;
#
#     top: 50%; left: -1.2em;
#     width: 1em; height: 1em;
#
#     margin-top: -0.5em;
#
#     content: "C";
#     font-family: neurolead!important;
#
#     color: white;
#     background: #58f;
#
#     border-radius: 50%!important;
#
#     line-height: 1em !important;
# }
#
# .nld-chatbot .nld-invite-message-container.nld-notification .nld-footer.nld-verified {
#     display: block;
#     opacity: 0;
#
#     text-align: right;
#
#     position: absolute;
#     right: 8px; bottom: 0;
#
#     font-size: 75%!important;
#     color: #58f;
#
#     animation: nld-slide-in 0.4s cubic-bezier(0,.35,.28,.9) forwards;
#     animation-delay: 0.5s;
# }
#
# .nld-chatbot .nld-invite-message-container.nld-notification .nld-footer.nld-time {
#     display: block;
#     opacity: 0;
#
#     position: absolute;
#     left: 92px; bottom: 0;
#
#     font-size: 75%!important;
#     color: #aaa;
#
#     animation: nld-slide-in 0.4s cubic-bezier(0,.35,.28,.9) forwards;
#     animation-delay: 0.25s;
# }
#
# .nld-chatbot.nld-left .nld-invite-message-container.nld-notification .nld-footer.nld-time {
#     left: 16px;
#     text-align: left;
# }
#
# .nld-chatbot.nld-left .nld-invite-message-container.nld-notification .nld-footer.nld-verified {
#     right: 86px;
#     text-align: right;
# }
#
# .nld-chatbot .nld-invite-message-container.nld-notification .nld-invite-message-text {
#     min-width: 180px;
#     margin-bottom: 16px;
#     line-height: 1.2em !important;
#
#     align-self: flex-start;
# }
#
# @keyframes nld-pulse {
#     0% { top: 50%; left: 50%; width: 0; height: 0; opacity: 1; }
#     60% {  top: -25%; left: -25%; width: 150%; height: 150%; opacity: 0; }
#     100% { opacity: 0; top: 50%; left: 50%; width: 0; height: 0; }
# }
#
# .nld-chatbot .nld-popup-container {
#     position: absolute;
#     bottom: 3.5em;
#     width: 100%;
#     left: 0;
# }
#
# .nld-chatbot .nld-popup-container .nld-popup {
#    margin: 0 0.75em;
#    background: #fff0f1;
#    border-radius: 0.5em;
#    box-shadow: 0 4px 6px -5px rgba(0, 0, 0, 0.2);
#    border: 1px solid #f2dcd0;
#    color: #a33;
#    padding: 1em 2em;
#    text-align: center;
#    font-size: 1.25em!important;
# }
#
# /* Glider.js */
#
# .glider-contain {
#     width: 100%;
#     margin: 0 auto;
#     position: relative;
# }
# .glider {
#     margin: 0 auto;
#     position: relative;
#     overflow-y: hidden;
#     -webkit-overflow-scrolling: touch;
#     -ms-overflow-style: none;
#     transform: translateZ(0);
# }
# .glider-track {
#     transform: translateZ(0);
#     width: 100%;
#     margin: 0;
#     padding: 0;
#     display: flex;
#     z-index: 1;
# }
# .glider.draggable {
#     user-select: none;
#     cursor: -webkit-grab;
#     cursor: grab;
# }
# .glider.draggable .glider-slide img {
#     user-select: none;
#     pointer-events: none;
# }
# .glider.drag {
#     cursor: -webkit-grabbing;
#     cursor: grabbing;
# }
# .glider-slide {
#     user-select: none;
#     justify-content: center;
#     align-content: center;
#     width: 100%;
# }
# .glider-slide img {
#     max-width: 100%;
# }
# .glider::-webkit-scrollbar {
#     opacity: 0;
#     height: 0;
# }
# .glider-prev,.glider-next {
#     user-select: none;
#     position: absolute;
#     outline: none;
#     background: none;
#     padding: 0;
#     z-index: 2;
#     font-size: 40px;
#     text-decoration: none;
#     left: -23px;
#     border: 0;
#     top: 30%;
#     cursor: pointer;
#     color: #666;
#     opacity: 1;
#     line-height: 1 !important;
#     transition: opacity .5s cubic-bezier(.17,.67,.83,.67),
#     color .5s cubic-bezier(.17,.67,.83,.67);
# }
# .glider-prev:hover,
# .glider-next:hover,
# .glider-prev:focus,
# .glider-next:focus {
#     color: #a89cc8;
# }
# .glider-next {
#     right: -23px;
#     left: auto;
# }
# .glider-next.disabled,
# .glider-prev.disabled {
#     opacity: .25;
#     color: #666;
#     cursor: default;
# }
# .glider-slide {
#     min-width: 150px;
# }
# .glider-hide {
#     opacity: 0;
# }
# .glider-dots {
#     user-select: none;
#     display: flex;
#     flex-wrap: wrap;
#     justify-content: center;
#     margin: 0 auto;
#     padding: 0;
# }
# .glider-dot {
#     background: none;
#     border: 0;
#     padding: 0;
#     user-select: none;
#     outline: none;
#     display: block;
#     cursor: pointer;
#     color: #ccc;
#     border-radius: 999px!important;
#     background: #ccc;
#     width: 12px;
#     height: 12px;
#     margin: 7px;
# }
# .glider-dot:hover,
# .glider-dot:focus,
# .glider-dot.active {
#     background: #a89cc8;
# }
# @media(max-width: 36em){
#     .glider::-webkit-scrollbar {
#         opacity: 1;
#         -webkit-appearance: none;
#         width: 7px;
#         height: 3px;
#     }
#     .glider::-webkit-scrollbar-thumb {
#         opacity: 1;
#         border-radius: 99px!important;
#         background-color: rgba(156, 156, 156, 0.25);
#         box-shadow: 0 0 1px rgba(255,255,255,.25);
#     }
# }
#
# .opacity-hover:hover {
#   opacity: 0.9;
# }
#   </style>
#   <style type="text/css">
#    .nld-chatbot .countries_list_btn {
#   border: none;
#   cursor: pointer;
#   display: flex;
#   align-items: center;
#   position: absolute;
#   background-color: transparent;
#   outline: none;
#   height: 30px;
#   bottom: 6px;
#   left: 24px
# }
#
# .nld-chatbot .countries_list_btn:focus{
#   outline-style: none;
# }
#
# .nld-chatbot .countriesList {
#   position: relative;
#   display: inline-block;
# }
#
# .nld-chatbot .countries_list_content {
#   display: none;
#   position: absolute;
#   z-index: 1;
#   height: 350px;
#   overflow: auto;
#   background-color: #fff;
#   bottom: 50px;
#   left: 15px;
#   right: 15px;
#   border: solid 2px;
#   border-radius: 10px;
# }
#
#
# .nld-chatbot .countries_list_content a {
#   color: black;
#   padding: 0px 10px;
#   text-decoration: none;
#   cursor: pointer;
#   display: block;
# }
#
# .nld-chatbot .countries_list_content a:hover {background-color: #f1f1f1}
#
# .nld-chatbot .countriesList:hover .countries_list_content {
#   display: block;
# }
#
# .nld-chatbot .arrow {
#   border: solid gray;
#   border-width: 0 2px 2px 0;
#   display: inline-block;
#   padding: 2px;
# }
#
# .nld-chatbot .down {
#   transform: rotate(45deg);
#   -webkit-transform: rotate(45deg);
#   margin: 5px;
# }
#
# .nld-chatbot .telinput {
#   border: 0;
# }
#
# .nld-chatbot .telinput:focus{
#   outline: none;
# }
#
# .nld-chatbot .tel {
#   align-items: center;
#   border: solid 1px grey;
#   width: fit-content;
# }
#
# .nld-chatbot .iti {
#   position: relative;
#   display: inline-block;
# }
#
# .nld-chatbot .iti * {
#   box-sizing: border-box;
#   -moz-box-sizing: border-box;
# }
#
# .nld-chatbot .iti__flag-box {
#   margin-right: 10px;
# }
#
# .nld-chatbot .iti__dial-code {
#   color: #999;
# }
#
# .nld-chatbot .iti__flag-country {
#   display: flex;
#   align-items: center;
#   padding: 5px 0px;
# }
#
# .nld-chatbot .iti__dial-code {
#   padding-left: 10px;
# }
#
# .nld-chatbot .iti__flag {
#   width: 20px;
# }
#
# @media (-webkit-min-device-pixel-ratio: 2), (min-resolution: 192dpi) {
#   .nld-chatbot .iti__flag {
#     background-size: 5652px 15px;
#   }
# }
#
# .nld-chatbot .iti__flag.iti__be {
#   width: 18px; }
# .nld-chatbot .iti__flag.iti__ch {
#   width: 15px; }
# .nld-chatbot .iti__flag.iti__mc {
#   width: 19px; }
# .nld-chatbot .iti__flag.iti__ne {
#   width: 18px; }
# .nld-chatbot .iti__flag.iti__np {
#   width: 13px; }
# .nld-chatbot .iti__flag.iti__va {
#   width: 15px; }
# .nld-chatbot .iti__flag.iti__ac {
#   height: 10px;
#   background-position: 0px 0px; }
# .nld-chatbot .iti__flag.iti__ad {
#   height: 14px;
#   background-position: -22px 0px; }
# .nld-chatbot .iti__flag.iti__ae {
#   height: 10px;
#   background-position: -44px 0px; }
# .nld-chatbot .iti__flag.iti__af {
#   height: 14px;
#   background-position: -66px 0px; }
# .nld-chatbot .iti__flag.iti__ag {
#   height: 14px;
#   background-position: -88px 0px; }
# .nld-chatbot .iti__flag.iti__ai {
#   height: 10px;
#   background-position: -110px 0px; }
# .nld-chatbot .iti__flag.iti__al {
#   height: 15px;
#   background-position: -132px 0px; }
# .nld-chatbot .iti__flag.iti__am {
#   height: 10px;
#   background-position: -154px 0px; }
# .nld-chatbot .iti__flag.iti__ao {
#   height: 14px;
#   background-position: -176px 0px; }
# .nld-chatbot .iti__flag.iti__aq {
#   height: 14px;
#   background-position: -198px 0px; }
# .nld-chatbot .iti__flag.iti__ar {
#   height: 13px;
#   background-position: -220px 0px; }
# .nld-chatbot .iti__flag.iti__as {
#   height: 10px;
#   background-position: -242px 0px; }
# .nld-chatbot .iti__flag.iti__at {
#   height: 14px;
#   background-position: -264px 0px; }
# .nld-chatbot .iti__flag.iti__au {
#   height: 10px;
#   background-position: -286px 0px; }
# .nld-chatbot .iti__flag.iti__aw {
#   height: 14px;
#   background-position: -308px 0px; }
# .nld-chatbot .iti__flag.iti__ax {
#   height: 13px;
#   background-position: -330px 0px; }
# .nld-chatbot .iti__flag.iti__az {
#   height: 10px;
#   background-position: -352px 0px; }
# .nld-chatbot .iti__flag.iti__ba {
#   height: 10px;
#   background-position: -374px 0px; }
# .nld-chatbot .iti__flag.iti__bb {
#   height: 14px;
#   background-position: -396px 0px; }
# .nld-chatbot .iti__flag.iti__bd {
#   height: 12px;
#   background-position: -418px 0px; }
# .nld-chatbot .iti__flag.iti__be {
#   height: 15px;
#   background-position: -440px 0px; }
# .nld-chatbot .iti__flag.iti__bf {
#   height: 14px;
#   background-position: -460px 0px; }
# .nld-chatbot .iti__flag.iti__bg {
#   height: 12px;
#   background-position: -482px 0px; }
# .nld-chatbot .iti__flag.iti__bh {
#   height: 12px;
#   background-position: -504px 0px; }
# .nld-chatbot .iti__flag.iti__bi {
#   height: 12px;
#   background-position: -526px 0px; }
# .nld-chatbot .iti__flag.iti__bj {
#   height: 14px;
#   background-position: -548px 0px; }
# .nld-chatbot .iti__flag.iti__bl {
#   height: 14px;
#   background-position: -570px 0px; }
# .nld-chatbot .iti__flag.iti__bm {
#   height: 10px;
#   background-position: -592px 0px; }
# .nld-chatbot .iti__flag.iti__bn {
#   height: 10px;
#   background-position: -614px 0px; }
# .nld-chatbot .iti__flag.iti__bo {
#   height: 14px;
#   background-position: -636px 0px; }
# .nld-chatbot .iti__flag.iti__bq {
#   height: 14px;
#   background-position: -658px 0px; }
# .nld-chatbot .iti__flag.iti__br {
#   height: 14px;
#   background-position: -680px 0px; }
# .nld-chatbot .iti__flag.iti__bs {
#   height: 10px;
#   background-position: -702px 0px; }
# ...
#       <div class="item-block-list">
#        <div class="image">
#         <a href="https://www.ameximoveis.com.br/imovel/12580/apartamento/agua-verde/curitiba" target="_blank">
#          <img alt="Amex Imóveis" src="https://sigavi360.s3-sa-east-1.amazonaws.com/amex/arquivo/imovel/12580/foto/20220625131849391-1.jpg"/>
#         </a>
#        </div>
#        <div class="info">
#         <div class="badges">
#          <span class="badge">
#           Apartamento
#          </span>
#         </div>
#         <h5>
#          Água Verde
#         </h5>
#         <h4>
#          Curitiba
#         </h4>
#         <div class="specs">
#          <div class="spec-item">
#           <i class="icon-spec-bedroom">
#           </i>
#           <span>
#            2 quartos
#           </span>
#          </div>
#          <div class="spec-item">
#           <i class="icon-bathtub">
#           </i>
#           <span>
#            1 suíte
#           </span>
#          </div>
#          <div class="spec-item">
#           <i class="icon-spec-bath">
#           </i>
#           <span>
#            2 banheiros
#           </span>
#          </div>
#          <div class="spec-item">
#           <i class="icon-spec-garage">
#           </i>
#           <span>
#            1 garagem
#           </span>
#          </div>
#          <div class="spec-item">
#           <i class="icon-spec-size">
#           </i>
#           <span>
#            63,00 m²
#           </span>
#          </div>
#         </div>
#         <div class="price">
#          <h5>
#           Venda R$ 630.000,00
#          </h5>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="loading" style="display: none;">
#       <img alt="Amex Imóveis" src="https://www.ameximoveis.com.br/_app/images/spinner.svg"/>
#      </div>
#     </section>
#    </div>
#   </main>
#   <footer>
#    <div class="content">
#     <div class="upper">
#      <div class="logo">
#       <img alt="Amex Imóveis" src="https://www.ameximoveis.com.br/_app/images/logo.png"/>
#      </div>
#      <div class="menus">
#       <div class="box">
#        <h4>
#         Sobre
#        </h4>
#        <ul>
#         <li>
#          <a href="https://www.ameximoveis.com.br/quem-somos">
#           Quem Somos
#          </a>
#         </li>
#         <li>
#          <a href="https://www.ameximoveis.com.br/fale-conosco">
#           Fale Conosco
#          </a>
#         </li>
#        </ul>
#        <br/>
#        <h4>
#         Cidade
#        </h4>
#        <ul>
#         <li>
#          <a href="https://www.ameximoveis.com.br/cidade/balneario-camboriu" target="_blank">
#           Balneario Camboriu
#          </a>
#         </li>
#         <li>
#          <a href="https://www.ameximoveis.com.br/cidade/camboriu" target="_blank">
#           Camboriu
#          </a>
#         </li>
#         <li>
#          <a href="https://www.ameximoveis.com.br/cidade/curitiba" target="_blank">
#           Curitiba
#          </a>
#         </li>
#         <li>
#          <a href="https://www.ameximoveis.com.br/cidade/guaratuba" target="_blank">
#           Guaratuba
#          </a>
#         </li>
#         <li>
#          <a href="https://www.ameximoveis.com.br/cidade/itajai" target="_blank">
#           Itajai
#          </a>
#         </li>
#         <li>
#          <a href="https://www.ameximoveis.com.br/cidade/itapema" target="_blank">
#           Itapema
#          </a>
#         </li>
#         <li>
#          <a href="https://www.ameximoveis.com.br/cidade/pinhais" target="_blank">
#           Pinhais
#          </a>
#         </li>
#         <li>
#          <a href="https://www.ameximoveis.com.br/cidade/sao-jose-dos-pinhais" target="_blank">
#           São José dos Pinhais
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="box">
#        <h4>
#         Imóveis
#        </h4>
#        <ul>
#         <li>
#          <a href="https://www.ameximoveis.com.br/categoria/apartamento" target="_blank">
#           Apartamento
#          </a>
#         </li>
#         <li>
#          <a href="https://www.ameximoveis.com.br/categoria/apartamento-duplex" target="_blank">
#           Apartamento Duplex
#          </a>
#         </li>
#         <li>
#          <a href="https://www.ameximoveis.com.br/categoria/apartamento-garden" target="_blank">
#           Apartamento Garden
#          </a>
#         </li>
#         <li>
#          <a href="https://www.ameximoveis.com.br/categoria/barraco" target="_blank">
#           Barracão
#          </a>
#         </li>
#         <li>
#          <a href="https://www.ameximoveis.com.br/categoria/casa" target="_blank">
#           Casa
#          </a>
#         </li>
#         <li>
#          <a href="https://www.ameximoveis.com.br/categoria/casa-em-condominio" target="_blank">
#           Casa em Condomínio
#          </a>
#         </li>
#         <li>
#          <a href="https://www.ameximoveis.com.br/categoria/cobertura-duplex" target="_blank">
#           Cobertura Duplex
#          </a>
#         </li>
#         <li>
#          <a href="https://www.ameximoveis.com.br/categoria/cobertura-horizontal" target="_blank">
#           Cobertura Horizontal
#          </a>
#         </li>
#         <li>
#          <a href="https://www.ameximoveis.com.br/categoria/cobertura-triplex" target="_blank">
#           Cobertura Triplex
#          </a>
#         </li>
#         <li>
#          <a href="https://www.ameximoveis.com.br/categoria/loja" target="_blank">
#           Loja
#          </a>
#         </li>
#         <li>
#          <a href="https://www.ameximoveis.com.br/categoria/sala-comercial" target="_blank">
#           Sala Comercial
#          </a>
#         </li>
#         <li>
#          <a href="https://www.ameximoveis.com.br/categoria/sobrado" target="_blank">
#           Sobrado
#          </a>
#         </li>
#         <li>
#          <a href="https://www.ameximoveis.com.br/categoria/sobrado-em-condominio" target="_blank">
#           Sobrado em Condomínio
#          </a>
#         </li>
#         <li>
#          <a href="https://www.ameximoveis.com.br/categoria/studio" target="_blank">
#           Studio
#          </a>
#         </li>
#         <li>
#          <a href="https://www.ameximoveis.com.br/categoria/terreno-em-condominio" target="_blank">
#           Terreno em Condomínio
#          </a>
#         </li>
#         <li>
#          <a href="https://www.ameximoveis.com.br/categoria/terreno-lote-comercial" target="_blank">
#           Terreno/Lote Comercial
#          </a>
#         </li>
#         <li>
#          <a href="https://www.ameximoveis.com.br/categoria/terrenolote-residencial" target="_blank">
#           Terreno/Lote Residencial
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="box">
#        <h4>
#         Seu Imóvel
#        </h4>
#        <ul>
#         <li>
#          <a href="https://conteudo.ameximoveis.com.br/busca-personalizada-amex" target="_blank">
#           Buscamos seu Imóvel
#          </a>
#         </li>
#         <li>
#          <a href="https://www.ameximoveis.com.br/avaliacao">
#           Avalie seu Imóvel/Terreno
#          </a>
#         </li>
#         <li>
#          <a href="https://www.ameximoveis.com.br/anuncie">
#           Anuncie seu Imóvel
#          </a>
#         </li>
#         <li>
#          <a href="https://www.ameximoveis.com.br/proposta">
#           Proposta de Venda
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="box">
#        <h4>
#         Receba novidades
#        </h4>
#        <div class="newsletter">
#         <span>
#          Receba novidades diretamente em seu e-mail!
#         </span>
#         <form action="https://www.ameximoveis.com.br/newsletter" id="frmnews" method="post" name="frmnews">
#          <input id="email" name="email" placeholder="Seu e-mail" type="text"/>
#          <button id="btnnews" name="btnnews" type="submit">
#           Cadastrar
#          </button>
#         </form>
#        </div>
#       </div>
#       <div class="box">
#        <h4>
#         Siga-nos
#        </h4>
#        <div class="social">
#         <a href="https://www.facebook.com/ameximoveis.com.br/" target="_blank">
#          <i class="icon-facebook">
#          </i>
#         </a>
#         <a href="https://www.instagram.com/ameximoveis" target="_blank">
#          <i class="icon-instagram">
#          </i>
#         </a>
#         <a href="https://www.youtube.com/channel/UCPJ0zXbQ9Sr-IyMQ9Cr7pOg/playlists" target="_blank">
#          <i class="icon-youtube">
#          </i>
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="bottom">
#     <div class="content">
#      <span>
#       © Amex Imóveis 2022. Todos os direitos reservados.
#      </span>
#      <a href="https://www.feraweb.com.br" target="_blank">
#       <i class="icon-fw">
#       </i>
#      </a>
#     </div>
#    </div>
#   </footer>
#   <script>
#    var base_url = 'https://www.ameximoveis.com.br';
#   </script>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 	new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 	j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 	'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 	})(window,document,'script','dataLayer','GTM-PG637SH');
#   </script>
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PG637SH" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <script>
#    !function(f,b,e,v,n,t,s)
# 	{if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# 	n.callMethod.apply(n,arguments):n.queue.push(arguments)};
# 	if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
# 	n.queue=[];t=b.createElement(e);t.async=!0;
# 	t.src=v;s=b.getElementsByTagName(e)[0];
# 	s.parentNode.insertBefore(t,s)}(window, document,'script',
# 	'https://connect.facebook.net/en_US/fbevents.js');
# 	fbq('init', '999149477285959');
# 	fbq('track', 'PageView');
#   </script>
#   <noscript>
#    <img height="1" src="https://www.facebook.com/tr?id=999149477285959&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#   </noscript>
#   <!-- <script type="text/javascript" async src="https://d335luupugsy2.cloudfront.net/js/loader-scripts/e4d8e766-2b4c-4d05-9ab9-e0a55fdb0c9f-loader.js" ></script>
# 	-->
#   <a href="https://wa.me/554133360505?text=Olá. Acessei o site da Amex Imóveis e gostaria de mais informações sobre o imóvel." style="position:fixed;bottom:20px;right:30px;" target="_blank">
#    <svg enable-background="new 0 0 512 512" height="50" version="1.1" viewbox="0 0 512 512" width="50" xml:space="preserve" xmlns="http://www.w3.org/2000/svg">
#     <path d="M256.064,0h-0.128l0,0C114.784,0,0,114.816,0,256c0,56,18.048,107.904,48.736,150.048l-31.904,95.104  l98.4-31.456C155.712,496.512,204,512,256.064,512C397.216,512,512,397.152,512,256S397.216,0,256.064,0z" fill="#4CAF50">
#     </path>
#     <path d="m405.02 361.5c-6.176 17.44-30.688 31.904-50.24 36.128-13.376 2.848-30.848 5.12-89.664-19.264-75.232-31.168-123.68-107.62-127.46-112.58-3.616-4.96-30.4-40.48-30.4-77.216s18.656-54.624 26.176-62.304c6.176-6.304 16.384-9.184 26.176-9.184 3.168 0 6.016 0.16 8.576 0.288 7.52 0.32 11.296 0.768 16.256 12.64 6.176 14.88 21.216 51.616 23.008 55.392 1.824 3.776 3.648 8.896 1.088 13.856-2.4 5.12-4.512 7.392-8.288 11.744s-7.36 7.68-11.136 12.352c-3.456 4.064-7.36 8.416-3.008 15.936 4.352 7.36 19.392 31.904 41.536 51.616 28.576 25.44 51.744 33.568 60.032 37.024 6.176 2.56 13.536 1.952 18.048-2.848 5.728-6.176 12.8-16.416 20-26.496 5.12-7.232 11.584-8.128 18.368-5.568 6.912 2.4 43.488 20.48 51.008 24.224 7.52 3.776 12.48 5.568 14.304 8.736 1.792 3.168 1.792 18.048-4.384 35.52z" fill="#FAFAFA">
#     </path>
#    </svg>
#   </a>
#   <script src="https://www.ameximoveis.com.br/_app/bower_components/jquery/dist/jquery.min.js">
#   </script>
#   <script src="https://www.ameximoveis.com.br/_app/bower_components/swiper/dist/js/swiper.min.js">
#   </script>
#   <script src="https://www.ameximoveis.com.br/_app/bower_components/fancybox/dist/jquery.fancybox.min.js">
#   </script>
#   <script src="https://www.ameximoveis.com.br/_app/bower_components/select2/dist/js/select2.full.min.js">
#   </script>
#   <script src="https://www.ameximoveis.com.br/_app/bower_components/jquery-mask-plugin/dist/jquery.mask.min.js">
#   </script>
#   <script src="https://www.ameximoveis.com.br/_app/js/functions.js?v=">
#   </script>
#   <script type="text/javascript">
#    (function(n,r,l,d){try{var h=r.head||r.getElementsByTagName("head")[0],s=r.createElement("script");s.defer=true;s.setAttribute("type","text/javascript");s.setAttribute("src",l);n.neuroleadId=d;h.appendChild(s);}catch(e){}})(window,document,"https://cdn.leadster.com.br/neurolead/neurolead.min.js", 53457);
#   </script>
#   <script type="text/javascript">
#    var bairrosSelected = null;
# 	$("#bairro").select2().val(bairrosSelected).trigger("change");
#
# 	var tipoSelected = '';
# 	$("#tipo").select2().val(tipoSelected).trigger("change");
#
# 	var cidade = $('#cidade');
# 	if(cidade.val().length)
# 	{
# 		filtro_bairros_cidade();
# 	}
#
# 	function filtro_bairros_cidade() {
#
# 		cidade = $('#cidade');
#
# 		$.ajax({
# 			type: 'post',
# 			url: '/_app/ajax.bairro.cidade.php',
# 			data: {
# 			cidade:cidade.val()
# 			},
# 			success: function (response) {
#
# 				var newOptions = JSON.parse(response);
# 				var $listBairros = $('#bairro');
# 				var prevValue = $listBairros.val();
# 				$listBairros.empty();
# 				//$listBairros.append($('<option selected></option>').attr('value', '').text('Todos'));
# 				$.each(newOptions, function(key, value) {
# 				$listBairros.append($('<option></option>').attr('value', value).text(key));
# 				if (value === prevValue){
# 					$listBairros.val(value);
# 				}
# 				});
# 				$("#bairro").select2().val(bairrosSelected);
# 				$listBairros.trigger('change');
# 			}
#  		});
# 	}
#   </script>
#   <iframe id="_hjRemoteVarsFrame" name="_hjRemoteVarsFrame" src="https://vars.hotjar.com/box-0004cb77850b00d4aa7e1e08ff61e8f0.html" style="display: none !important; width: 1px !important; height: 1px !important; opacity: 0 !important; pointer-events: none !important;" title="_hjRemoteVarsFrame">
#   </iframe>
#   <iframe id="_hjSafeContext_35650029" src="about:blank" style="display: none !important; width: 1px !important; height: 1px !important; opacity: 0 !important; pointer-events: none !important;">
#   </iframe>
#   <div class="nld-chatbot nld-nodisplay">
#    <div class="nld-avatar nld-shown-slide">
#     <div class="nld-chatbot-invite-container">
#      <div class="nld-chatbot-invite-message">
#       <div class="nld-close nld-nodisplay">
#        <img alt="Close Button" class="nld-close-white" src="data:image/png;base64,..."/>
#       </div>
#       <span class="nld-invite-message-container nld-nodisplay">
#        <span class="nld-sp-icon nld-left nld-nodisplay">
#         <div>
#         </div>
#         <div>
#         </div>
#         <div class="nld-img">
#         </div>
#        </span>
#        <span class="nld-invite-message-text">
#        </span>
#        <span class="nld-sp-icon nld-right nld-nodisplay">
#         <div>
#         </div>
#         <div>
#         </div>
#         <div class="nld-img">
#         </div>
#        </span>
#        <span class="nld-footer nld-verified">
#         Verificado pela Leadster
#        </span>
#        <span class="nld-footer nld-time">
#        </span>
#       </span>
#       <div class="nld-typing-indicator">
#        <span>
#        </span>
#        <span>
#        </span>
#        <span>
#        </span>
#       </div>
#       <div class="nld-clear">
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="nld-conversation nld-hidden-slide nld-nodisplay">
#     <div class="nld-brand-footer">
#     </div>
#     <div class="nld-bg">
#      <div class="nld-conversation-header">
#       <a class="nld-close" href="javascript:void(0);">
#        <img alt="Close Button" class="nld-close-white" src="data:image/png;base64,..."/>
#       </a>
#       <img alt="" class="nld-3rdparty-branding"/>
#       <div class="nld-infobar">
#        <div class="nld-avatar">
#        </div>
#        <div class="nld-info">
#         <div class="nld-title">
#         </div>
#         <div class="nld-subtitle">
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="nld-ctx" id="context">
#      </div>
#     </div>
#     <div class="nld-popup-container nld-nodisplay">
#      <div class="nld-popup">
#      </div>
#     </div>
#    </div>
#   </div>
#   <iframe src="https://bid.g.doubleclick.net/xbbe/pixel?d=KAE" style="display: none;">
#   </iframe>
#  </body>
# </html>

# %%
# home url
home_url = 'https://www.realtor.com/international/br/'
# number of pages of search result are 200, so we need to 
page_numbers = list(range(3))[1:3]
# list to store all the urls of properties
list_of_links = []
# for loop for all 200 search pages
for page in page_numbers:
    # extracting html document of search page
    html1 = (home_url + '/p' + str(page) + '/?searchtypes=house+apartment')
    html = urlopen(html1)
    print(html1)
    # parsing html document to 'lxml' format
    bsobj = BeautifulSoup(html, 'lxml')
    # finding all the links available in 'ul' tag whos 'data-testid' is 'results'
    all_links = bsobj.find('ul', 'tier-one-listing-table').findAll('a', href=re.compile('/international/br/*'))
#for link1 in links.find('li', 'listing  ').findAll('a', href=re.compile('/international/br/*')):

for link1 in all_links:
        # checking if it is a project and then performing similar thing I did above
    if 'href' in link1.attrs['href']:
        inner1_html = urlopen(link1.attrs['href'])
        inner1_bsobj = BeautifulSoup(inner1_html, "lxml")
        for link2 in inner1_bsobj.find('li', 'listing  ').findAll('a', href=re.compile('/international/br/*')):
            if 'href' in link2.attrs:
                list_of_links.append(link2.attrs['href'])
    else:
        list_of_links.append(link1.attrs['href'])
# Out:
# https://www.realtor.com/international/br//p1/?searchtypes=house+apartment
# https://www.realtor.com/international/br//p2/?searchtypes=house+apartment

# %%
#list_of_links

# %%
# removing duplicate links while maintaining the order of urls
links = [] 
for i in list_of_links: 
    if i not in links: 
        links.append(i)

# %%
#links

# %%
# defining required regural expression for data extraction     
all_basic_feature = []
property_type_l = []
price_l = []
property_adress_l = []
lat_ = []
long_ = []

    
# loop to iterate through each url
for link in links:
    
    # opening urls
    home_url = 'https://www.realtor.com'
    html1 = (home_url + link)
    html = urlopen(html1)
    #print(html1)
    
    # converting html document to 'lxml' format
    bsobj = BeautifulSoup(html, "lxml")
    
    # extracting address/name of property
    #property_name = bsobj.find("address", 'address')
    if bsobj.find_all('li', "address"):
        property_adress_list = bsobj.find_all('li', "address")
        for property_adress in property_adress_list:
            property_adress = property_adress.find('span').text
        property_adress_l.append(property_adress)
    else:
        property_adress_l.append('NA - property adress')
        
    if bsobj.find_all('div', "listing-map"):
        lat_list = bsobj.find_all('div', "listing-map")
        for lat in lat_list:
            lat = lat.find("data-latitude")
            lat_.append(lat)
    else:
        lat_.append('NA - latitude')
    
    # extracting baths, rooms, parking etc
    if bsobj.find_all(title="Bedrooms"):
        bedroom_list = bsobj.find_all(title="Bedrooms")
        for bedroom in bedroom_list:
            bedrooms = bedroom.find('strong').text
            #print(bedrooms)
        all_basic_feature.append(bedrooms)
    else:
        all_basic_feature.append('NA - bedroom')

    if bsobj.find_all(title="Bathrooms"):
        bathroom_list = bsobj.find_all(title="Bathrooms")
        for bathroom in bathroom_list:
            bathrooms = bathroom.find('strong').text
            #print(bathrooms)
        all_basic_feature.append(bathrooms)
    else:
        all_basic_feature.append('NA - bathroom')

    if bsobj.find_all(title="House Size"):
        house_size_list = bsobj.find_all(title="House Size")
        for house_size in house_size_list:
            house_size = house_size.find('strong').text
            #print(house_size)
        all_basic_feature.append(house_size)
    else:
        all_basic_feature.append('NA - house size')
        

    
    # extracting property price
    #property_price = bsobj.find("p", 'listing-price specified')
    if bsobj.find_all("p", 'listing-price specified'):
        price_list = bsobj.find_all("p", 'listing-price specified')
        for price in price_list:
            price = price.find('strong').text.replace('\n            \n                BRL R$','').replace(' \n            \n            ','')
        price_l.append(price)
    else:
        price_l.append('NA - price')
    
     # extracting property type (house, ap...)
    if bsobj.find_all('div','propertytype'):
        property_type_list = bsobj.find_all('div','propertytype')
        for property_type in property_type_list:
            property_type = property_type.find('span').text
        property_type_l.append(property_type)
    else:
        property_type_l.append('NA - property type')
    #property_type = bsobj.find("div", 'propertytype')
    
    # extracting latitudes and longitudes
    #lat_long = bsobj.find("a", {"target": "_blank", 'rel': "noopener noreferer"})
    

    
lat_
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36' ,
    'referer':'https://www.google.com/'}

site = requests.get('https://www.realtor.com/international/br/?searchtypes=house+apartment&sort=price+desc',headers = headers)

site
# Out:
# <Response [200]>

# %%
#req = Request('https://www.realtor.com/realestateandhomes-search/California',headers = headers)
#site = urlopen(req).read()
#site

# %%
r = site.text
r = BeautifulSoup(r, 'html.parser')
r
# Out:
# <script>
#         window.safeframeAD = true;
#     </script>
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1, user-scalable=0" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <meta content="webkit" name="renderer"/> <!-- for 360 Secure Browser -->
# <meta content="index, follow" name="robots"/>
# <meta content="Kz0mmgvzzSMFJ86g74e3ePoxMNd--vNBLPCkNXslxwA" name="google-site-verification">
# <meta content="no-transform" http-equiv="Cache-Control">
# <link href="//s1.rea.global" rel="dns-prefetch"/>
# <link href="//s2.rea.global" rel="dns-prefetch"/>
# <link href="//s3.rea.global" rel="dns-prefetch"/>
# <link href="//s4.rea.global" rel="dns-prefetch"/>
# <link href="//www.adobetag.com" rel="dns-prefetch"/>
# <link href="//reagroup.122.2o7.net" rel="dns-prefetch"/>
# <link href="https://d.la1t1.salesforceliveagent.com" rel="dns-prefetch"/>
# <link href="http://reagroup.sc.omtrdc.net" rel="dns-prefetch"/>
# <link href="//s4.rea.global/client/realtor/images/favicon-1a922d8db6afcaad.ico" rel="icon" type="image/x-icon"/>
# <link href="//s4.rea.global/client/realtor/images/apple_touch_icon-3671849ffef53406.png" rel="apple-touch-icon"/>
# <title>
#     Property for Sale in Brazil - realtor.com
# </title>
# <link href="https://www.realtor.com/international/br/" rel="canonical">
# <link href="https://www.realtor.com/international/br/" hreflang="en-us" rel="alternate"/>
# <link href="https://www.iproperty.com.my/international/br/" hreflang="en-my" rel="alternate"/>
# <link href="https://housing.com/international/br/" hreflang="en-in" rel="alternate"/>
# <link href="https://thinkofliving.com/international/br/" hreflang="th-th" rel="alternate"/>
# <link href="https://www.realestate.com.au/international/br/" hreflang="en-au" rel="alternate"/>
# <link as="font" crossorigin="" href="//s4.rea.global/fonts/avartar-uz556w.ttf" rel="preload" type="font/ttf"/>
# <script>
#         window.utag_cfg_ovrd = { noview: true };
#         Object.defineProperty(window, "@argonaut/analytics/loadTealium", {
#                 value: (function createBasicPromise(setup) {
#                         var callbacks = [];
#                         var resolved = false;
#                         setup(function resolve() {
#                                 resolved = true;
#                                 for (var i = 0; i < callbacks.length; i++) {
#                                         var callback = callbacks[i];
#                                         callback();
#                                 }
#                         });
#                         return function then(callback) {
#                                 if (resolved) {
#                                         callback();
#                                 } else {
#                                         callbacks.push(callback);
#                                 }
#                         };
#                 })(function loadTealium(resolve) {
#                         var s = document.createElement("script");
#                         s.async = true;
#                         s.setAttribute(
#                                 "src",
#                                 '//tags.tiqcdn.com/utag/rea-group/international/prod/utag.js'
#                         );
#                         s.addEventListener("load", resolve);
#                         document.head.appendChild(s);
#                 }),
#         });
#         (function(a,b,c,d){a='//s4.rea.global/js/lib/tealium/argonaut.no_uglify.spcl-d5d6b7eb2ec01458.js';b=document;c='script';d=b.createElement(c);d.src=a;d.type='text/java'+c;d.async=true;a=b.getElementsByTagName(c)[0];a.parentNode.insertBefore(d,a);})();
#         function aTrack(context, event, type, clear) {
#             if (typeof window.enable_tealium_tracking === "undefined" || window.enable_tealium_tracking === false) {
#                 return;
#             }
#             window.argonaut_start_time || (window.argonaut_start_time = new Date),
#                     "object" == typeof window.argonaut && "function" == typeof window.argonaut.track ? window.argonaut.track(context, event, type, clear) :
#                             1e4 < new Date - window.argonaut_start_time || setTimeout(function() {aTrack(context, event, type, clear)}, 500)
#         }
#         window.aTrack = aTrack;
#         window.enable_tealium_tracking = true;
# </script>
# <script>
#         function getCookie(name) {
#             var value = "; " + document.cookie;
#             var parts = value.split("; " + name + "=");
#             if (parts.length == 2) return parts.pop().split(";").shift();
#         }
#         var reaAnalyticsData = {
#             pageInfo: {
#                 pageName: "intlapp:br:buy:search_result_page",
#                 siteSection: "buy",
#                 hierarchy: "br:buy:search_result_page",
#                 pageType: "search_result_page",
#                 clientId: "realtor",
#                 pageNumber: "1"
#             },
#
#             listingInfo: {
#                 listingId: "120040138907,120077229157,120077207637,120069539378,120077229514,120077224873,120077211994,120061924943,120077947247,120052112268,120077229492,120052112628,120052068267,120077206199,120076601787,120077228967,120052056487,120077221011,120077207654,120077228597",
#                 listingProviderId: "realtor,realtor,realtor,realtor,realtor,realtor,realtor,realtor,realtor,realtor,realtor,realtor,realtor,realtor,realtor,realtor,realtor,realtor,realtor,realtor",
#                 sourceListingId: ""
#             },
#
#             searchInfo: {
#                 searchType: "",
#                 isRepeatedSearch: getCookie("lastVisitedPage") === "detail" ? "yes" : "no"
#             },
#
#             locationInfo: {
#                 country: "BR",
#                 state: "",
#                 city_region: "",
#                 postcode: "",
#                 typed_location: ""
#             }
#         };
#     </script>
# <meta content="Find Property for sale in Brazil. Search for real estate and find the latest listings of Brazil Property for sale." name="description"/>
# <link href="/international/br/p2/?searchtypes=house+apartment&amp;sort=price+desc" rel="next">
# <style>
#     body {background-color: #F7F8F9; margin: 0}
#   </style>
# <link as="image" href="//s1.rea.global/img/400x300-crop/realtor/br/deb543c12244215a7f87aa3ae609670d.jpg" rel="preload">
# <link as="image" href="//s1.rea.global/img/400x300-crop/realtor/br/4b6fe60a613fd25bbe4c3d7b39cfef5e.jpg" rel="preload">
# <link href="//s4.rea.global/client/realtor/css/result-412dfc9dcc1ceca7.css" rel="stylesheet">
# <script language="JavaScript">
#     window.tealiumData = {
#         view: {
#             page:  {
#                 data: {
#                     page_type: "search result - list",
#                     site: "gpn",
#                     site_section: "realtor",
#                     site_sub_section: "buy",
#                     language: "english",
#
#                 }
#             },
#             listing_search_results: {
#                 data: {
#                     listings_total: 12581,
#                     results_count: 20,
#                     page_number: 1,
#                     listings:[
#
#                         {
#                             id: "120040138907",
#                             product_depth: "basic",
#                             provider_name: "realtor",
#                             is_project: false,
#
#
#                         },
#
#                         {
#                             id: "120077229157",
#                             product_depth: "basic",
#                             provider_name: "realtor",
#                             is_project: false,
#
#
#                         },
#
#                         {
#                             id: "120077207637",
#                             product_depth: "basic",
#                             provider_name: "realtor",
#                             is_project: false,
#
#
#                         },
#
#                         {
#                             id: "120069539378",
#                             product_depth: "basic",
#                             provider_name: "realtor",
#                             is_project: false,
#
#
#                         },
#
#                         {
#                             id: "120077229514",
#                             product_depth: "basic",
#                             provider_name: "realtor",
#                             is_project: false,
#
#
#                         },
#
#                         {
#                             id: "120077224873",
#                             product_depth: "basic",
#                             provider_name: "realtor",
#                             is_project: false,
#
#
#                         },
#
#                         {
#                             id: "120077211994",
#                             product_depth: "basic",
#                             provider_name: "realtor",
#                             is_project: false,
#
#
#                         },
#
#                         {
#                             id: "120061924943",
#                             product_depth: "basic",
#                             provider_name: "realtor",
#                             is_project: false,
#
#
#                         },
#
#                         {
#                             id: "120077947247",
#                             product_depth: "basic",
#                             provider_name: "realtor",
#                             is_project: false,
#
#
#                         },
#
#                         {
#                             id: "120052112268",
#                             product_depth: "basic",
#                             provider_name: "realtor",
#                             is_project: false,
#
#
#                         },
#
#                         {
#                             id: "120077229492",
#                             product_depth: "basic",
#                             provider_name: "realtor",
#                             is_project: false,
#
#
#                         },
#
#                         {
#                             id: "120052112628",
#                             product_depth: "basic",
#                             provider_name: "realtor",
#                             is_project: false,
#
#
#                         },
#
#                         {
#                             id: "120052068267",
#                             product_depth: "basic",
#                             provider_name: "realtor",
#                             is_project: false,
#
#
#                         },
#
#                         {
#                             id: "120077206199",
#                             product_depth: "basic",
#                             provider_name: "realtor",
#                             is_project: false,
#
#
#                         },
#
#                         {
#                             id: "120076601787",
#                             product_depth: "basic",
#                             provider_name: "realtor",
#                             is_project: false,
#
#
#                         },
#
#                         {
#                             id: "120077228967",
#                             product_depth: "basic",
#                             provider_name: "realtor",
#                             is_project: false,
#
#
#                         },
#
#                         {
#                             id: "120052056487",
#                             product_depth: "basic",
#                             provider_name: "realtor",
#                             is_project: false,
#
#
#                         },
#
#                         {
#                             id: "120077221011",
#                             product_depth: "basic",
#                             provider_name: "realtor",
#                             is_project: false,
#
#
#                         },
#
#                         {
#                             id: "120077207654",
#                             product_depth: "basic",
#                             provider_name: "realtor",
#                             is_project: false,
#
#
#                         },
#
#                         {
#                             id: "120077228597",
#                             product_depth: "basic",
#                             provider_name: "realtor",
#                             is_project: false,
#
#
#                         },
#
#                     ]
#                 }
#             },
#
#             first_search_result: {
#                 data: {
#
#                     agency_id: "327042",
#                     price: "184869k",
#
#                     state: "Rio-de-Janeiro",
#                     suburb: "Rio-de-Janeiro",
#
#
#
#
#                     property_type: "Apartment",
#                     construction_status: "established"
#
#                 }
#             },
#
#             listing_search_parameters: {
#                 data: {
#                     sort_by: "price-high-to-low",
#                     localities: [{
#
#                         display: "BR",
#                         precision: "country",
#
#                         state: null,
#                         country: "BR"
#                     }],
#                     include_surrounding_suburbs: true,
#                     locations_requested: ["BR"],
#
#
#
#
#
#                     property_type: [
#
#                         "house",
#
#                         "apartment",
#
#                     ]
#                 }
#             },
#             user: {
#                 data: {
#
#                 }
#             }
#         }
#     }
# </script>
# <!--[if lt IE 9]>
#         <script>
#             document.getElementsByTagName('html')[0].className += 'old-ie';
#         </script>
#         <script src="//s4.rea.global/js/lib/html5shiv-2e15f7c701616c2e.js" type="text/javascript"></script>
#     <![endif]-->
# <script>
#         var assetUrl = '//s4.rea.global/';
#         var supportCountries = 'ar,bs,hn,cr,jm,cl,mx,ca,pa,co,pe,ec,br,us,bz,dm,do,bb,sv,ag,mq,gf,gp,tc,lc,aw,ky,cw,gd,gt,ht,kn,ni,pr,py,vc,vg,vi,pt,fr,hr,lv,es,it,cy,pl,ie,ch,ro,gr,gb,bg,de,sk,mt,be,at,lu,al,si,hu,ua,ad,ee,tr,gi,cz,fi,nl,no,rs,me,cn,in,ph,th,jp,sg,id,hk,my,mo,pk,kh,mm,vn,tw,bd,mn,lk,ae,il,jo,om,ma,cv,eg,mu,re,dz,gh,bi,ke,mg,tn,zm,nz,au,fj,vu';
#     </script>
# </link></link></link></link></link></meta></meta></meta></head>
# <body class="chrome chrome-74 en realtor" data-base-url="/international/" data-channel="buy" data-client="realtor" data-country="br" data-default-language="en" data-device="DESKTOP" data-lan-for-omni="" data-language="en" data-transparency="" data-updated-at="">
# <div class="client-color" hidden=""></div>
# <script type="text/javascript">(window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={xpid:"UAMDUlVRGwEDUVlbDgQO",licenseKey:"aebbba13a5",applicationID:"23589959"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var i,o=t("ee"),a=t(27),s={};try{i=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,i.indexOf("dev")!==-1&&(s.dev=!0),i.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&o.on("internal-error",function(t){r(t.stack)}),s.dev&&o.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{p?p-=1:i(s||new UncaughtException(t,e,n),!0)}catch(f){try{o("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function i(t,e){var n=e?null:c.now();o("err",[t,n])}var o=t("handle"),a=t(28),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError";if(!c.disabled){var p=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(10),t(9),"addEventListener"in window&&t(6),c.xhrWrappable&&t(11),d=!0)}s.on("fn-start",function(t,e,n){d&&(p+=1)}),s.on("fn-err",function(t,e,n){d&&!n[l]&&(f(n,l,function(){return!0}),this.thrown=!0,i(n))}),s.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),s.on("internal-error",function(t){o("ierr",[t,c.now(),!0])})}},{}],3:[function(t,e,n){var r=t("loader");r.disabled||(r.features.ins=!0)},{}],4:[function(t,e,n){function r(){var t=new PerformanceObserver(function(t,e){var n=t.getEntries();s(v,[n])});try{t.observe({entryTypes:["resource"]})}catch(e){}}function i(t){if(s(v,[window.performance.getEntriesByType(w)]),window.performance["c"+l])try{window.performance[h](m,i,!1)}catch(t){}else try{window.performance[h]("webkit"+m,i,!1)}catch(t){}}function o(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var a=t("ee"),s=t("handle"),c=t(10),f=t(9),u=t(5),d=t(19),l="learResourceTimings",p="addEventListener",h="removeEventListener",m="resourcetimingbufferfull",v="bstResource",w="resource",g="-start",y="-end",x="fn"+g,b="fn"+y,E="bstTimer",R="pushState",S=t("loader");if(!S.disabled){S.features.stn=!0,t(8),"addEventListener"in window&&t(6);var O=NREUM.o.EV;a.on(x,function(t,e){var n=t[0];n instanceof O&&(this.bstStart=S.now())}),a.on(b,function(t,e){var n=t[0];n instanceof O&&s("bst",[n,e,this.bstStart,S.now()])}),c.on(x,function(t,e,n){this.bstStart=S.now(),this.bstType=n}),c.on(b,function(t,e){s(E,[e,this.bstStart,S.now(),this.bstType])}),f.on(x,function(){this.bstStart=S.now()}),f.on(b,function(t,e){s(E,[e,this.bstStart,S.now(),"requestAnimationFrame"])}),a.on(R+g,function(t){this.time=S.now(),this.startPath=location.pathname+location.hash}),a.on(R+y,function(t){s("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),u()?(s(v,[window.performance.getEntriesByType("resource")]),r()):p in window.performance&&(window.performance["c"+l]?window.performance[p](m,i,d(!1)):window.performance[p]("webkit"+m,i,d(!1))),document[p]("scroll",o,d(!1)),document[p]("keypress",o,d(!1)),document[p]("click",o,d(!1))}}},{}],5:[function(t,e,n){e.exports=function(){return"PerformanceObserver"in window&&"function"==typeof window.PerformanceObserver}},{}],6:[function(t,e,n){function r(t){for(var e=t;e&&!e.hasOwnProperty(u);)e=Object.getPrototypeOf(e);e&&i(e)}function i(t){s.inPlace(t,[u,d],"-",o)}function o(t,e){retur ...
# <div class="cookie-header-container">
# <div class="site-notice-box" data-expired-days="30" style="display: block">
# <div class="canvas site-notice">
# <i class="icon-lock"></i>
#         This site is not intended for visitors from countries in the European Union. <br/>We use cookies to give you the best possible experience on our site and to analyse traffic. By continuing to use realtor.com/international, you agree to our use of cookies. View our <a href="https://marketing.move.com/privacy-policy/#cookies" target="_blank">Privacy Policy</a> for more information.<span class="notice-close">OK</span>
# <i class="icon-close"></i>
# </div>
# </div>
# <header>
# <nav class="global-navbar global-navbar-default global-nav-header unified-header-navbar" id="header-navbar">
# <div class="container">
# <div class="global-navbar-header">
# <button class="global-navbar-toggle" id="header-menu-btn">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# <a class="global-navbar-brand header-rdc-logo" data-no-turbolink="true" data-omtag="header-menu:network:realtor" href="https://www.realtor.com" id="header-rdc-logo">
# <img alt="realtor.com" id="main-logo" src="//s4.rea.global/client/realtor/images/logo-39175787b6331f1e.png"/>
# </a>
# <a class="move-network-links" data-container="body" data-original-title="" data-placement="bottom" data-popover-content="#move-network-popover" data-template='&lt;div class="popover global-nav-network-sites-popover" role="tooltip"&gt;&lt;div class="arrow"&gt;&lt;/div&gt;&lt;div class="popover-content"&gt;&lt;/div&gt;&lt;/div&gt;' data-toggle="popover" id="move-network-links" title="">
# <i class="svg-icon svg-icon-angle-down-header"></i>
# </a>
# </div>
# <div class="nav-menu-desktop" id="header-nav-menu">
# <ul class="global-nav global-navbar-nav global-navbar-main-links">
# <li class="dropdown">
# <a class="dropdown-toggle disabled dropdown-toggle-desktop" href="https://www.realtor.com/realestateforsale">BUY</a>
# </li>
# <li class="dropdown">
# <a class="dropdown-toggle disabled dropdown-toggle-desktop" href="https://www.realtor.com/sell">SELL</a>
# </li>
# <li class="dropdown">
# <a class="dropdown-toggle disabled dropdown-toggle-desktop" href="https://www.realtor.com/rentals">RENT</a>
# </li>
# <li class="dropdown">
# <a class="dropdown-toggle disabled dropdown-toggle-desktop" href="https://www.realtor.com/mortgage/">MORTGAGE</a>
# </li>
# <li class="dropdown">
# <a class="dropdown-toggle disabled dropdown-toggle-desktop" href="https://www.realtor.com/realestateagents/"><span>FIND</span>REALTORS<sup>®</sup></a>
# </li>
# <li class="dropdown">
# <a class="dropdown-toggle disabled dropdown-toggle-desktop" href="https://www.realtor.com/myhome">MY HOME</a>
# </li>
# <li class="dropdown">
# <a class="dropdown-toggle disabled dropdown-toggle-desktop" href="https://www.realtor.com/news/">NEWS &amp; INSIGHTS</a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <div class="normal-header unified-normal-header">
# <div class="inner">
# <div class="canvas clearfix default-header">
# <div class="logo-box">
# <a class="logo" href="https://www.realtor.com" title="realtor.com">
# <img alt="realtor.com" id="main-logo" src="//s4.rea.global/client/realtor/images/logo-39175787b6331f1e.png"/>
# </a>
# </div>
# <span class="hamburger x">
# <i class="lines"></i>
# </span>
# </div>
# </div>
# <nav class="hide">
# <div class="canvas nav-wrap">
# <ul class="nav">
# <li class="nav-item">
# <a href="https://www.realtor.com/realestateforsale">BUY</a>
# </li>
# <li class="nav-item">
# <a href="https://www.realtor.com/sell">SELL</a>
# </li>
# <li class="nav-item">
# <a href="https://www.realtor.com/rentals">RENT</a>
# </li>
# <li class="nav-item">
# <a href="https://www.realtor.com/mortgage/">MORTGAGE</a>
# </li>
# <li class="nav-item">
# <a href="https://www.realtor.com/realestateagents/"><span>FIND</span>REALTORS<sup>®</sup></a>
# </li>
# <li class="nav-item">
# <a href="https://www.realtor.com/myhome">MY HOME</a>
# </li>
# <li class="nav-item">
# <a href="https://www.realtor.com/news/">NEWS &amp; INSIGHTS</a>
# </li>
# </ul>
# <div class="settings-switch-wrapper settings-switch-menu">
# <div class="settings-switch-tabs">
# <ul class="current">
# <li class="settings-switch-tab" data-toggle="language">
# <i class="icon-global"></i>
# <span>EN</span>
# <select data-type="language" id="language-list">
# <option data-url="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" selected="" value="en">
#                                     English
#                                 </option>
# <option data-url="/international/br/?searchtypes=house+apartment&amp;sort=price+desc&amp;lang=de" value="de">
#                                     Deutsch
#                                 </option>
# <option data-url="/international/br/?searchtypes=house+apartment&amp;sort=price+desc&amp;lang=it" value="it">
#                                     Italiana
#                                 </option>
# <option data-url="/international/br/?searchtypes=house+apartment&amp;sort=price+desc&amp;lang=id" value="id">
#                                     Bahasa Indonesia
#                                 </option>
# <option data-url="/international/br/?searchtypes=house+apartment&amp;sort=price+desc&amp;lang=fr" value="fr">
#                                     Français
#                                 </option>
# <option data-url="/international/br/?searchtypes=house+apartment&amp;sort=price+desc&amp;lang=es" value="es">
#                                     Español
#                                 </option>
# <option data-url="/international/br/?searchtypes=house+apartment&amp;sort=price+desc&amp;lang=zh-tw" value="zh-tw">
#                                     繁體中文
#                                 </option>
# <option data-url="/international/br/?searchtypes=house+apartment&amp;sort=price+desc&amp;lang=zh-cn" value="zh-cn">
#                                     简体中文
#                                 </option>
# <option data-url="/international/br/?searchtypes=house+apartment&amp;sort=price+desc&amp;lang=th" value="th">
#                                     ภาษาไทย
#                                 </option>
# <option data-url="/international/br/?searchtypes=house+apartment&amp;sort=price+desc&amp;lang=pt" value="pt">
#                                     Português
#                                 </option>
# </select>
# </li>
# <li class="settings-switch-tab" data-toggle="currency">
# <i class="icon-currency"></i>
# <span>USD</span>
# <select data-type="currency" id="currency-list">
# <option data-url="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" selected="" value="USD">
#                                     USD - US Dollar
#                                 </option>
# <option data-url="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" value="JPY">
#                                     JPY - Japanese Yen
#                                 </option>
# <option data-url="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" value="AUD">
#                                     AUD - Australian Dollar
#                                 </option>
# <option data-url="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" value="CAD">
#                                     CAD - Canadian Dollar
#                                 </option>
# <option data-url="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" value="EUR">
#                                     EUR - Euro
#                                 </option>
# <option data-url="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" value="ILS">
#                                     ILS - Israeli Shekel
#                                 </option>
# <option data-url="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" value="INR">
#                                     INR - Indian Rupee
#                                 </option>
# <option data-url="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" value="ZAR">
#                                     ZAR - South African Rand
#                                 </option>
# <option data-url="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" value="NZD">
#                                     NZD - New Zealand Dollar
#                                 </option>
# <option data-url="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" value="MXN">
#                                     MXN - Mexican Peso
#                                 </option>
# <option data-url="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" value="ARS">
#                                     ARS - Argentine Peso
#                                 </option>
# <option data-url="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" value="CLP">
#                                     CLP - Chilean Peso
#                                 </option>
# <option data-url="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" value="PEN">
#                                     PEN - Peruvian Sol
#                                 </option>
# <option data-url="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" value="CHF">
#                                     CHF - Swiss Franc
#                                 </option>
# <option data-url="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" value="BRL">
#                                     BRL - Brazilian Real
#                                 </option>
# <option data-url="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" value="RUB">
#                                     RUB - Russian Ruble
#                                 </option>
# <option data-url="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" value="SGD">
#                                     SGD - Singapore Dollar
#                                 </option>
# <option data-url="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" value="CNY">
#                                     CNY - Chinese Yuan Renminbi
#                                 </option>
# <option data-url="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" value="MYR">
#                                     MYR - Malaysian Ringgit
#                                 </option>
# <option data-url="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" value="HKD">
#                                     HKD - Hong Kong Dollar
#                                 </option>
# </select>
# </li>
# <li class="settings-switch-tab" data-toggle="areaUnit">
# <i class="icon-floor-plan"></i>
# <span>sq ft</span>
# <select data-type="areaUnit" id="area-unit-list">
# <option data-url="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" value="Square meters">
#                                     m<sup>2</sup> - Square Meter
#                                 </option>
# <option data-url="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" selected="" value="Square feet">
#                                     sq ft - Square Foot
#                                 </option>
# </select>
# </li>
# <li class="settings-switch-tab" data-toggle="areaUnit">
# <i class="icon-measurement"></i>
# <span>mile</span>
# <select data-type="distanceUnit" id="distance-unit-list">
# <option data-url="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" value="Kilometers">
#                             km - Kilometer
#                             </option>
# <option data-url="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" selected="" value="Miles">
#                             mile - Mile
#                             </option>
# </select>
# </li>
# </ul>
# <div class="close"><i class="icon-close"></i></div>
# </div>
# <ul class="list-box">
# <li class="list" data-type="language">
# <h6 class="list-title">Language</h6>
# <ul class="list-content">
# <li class="list-item active">
# <a data-code="en" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                 English
#                             </a>
# </li>
# <li class="list-item">
# <a data-code="de" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc&amp;lang=de" rel="nofollow">
#                                 Deutsch
#                             </a>
# </li>
# <li class="list-item">
# <a data-code="it" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc&amp;lang=it" rel="nofollow">
#                                 Italiana
#                             </a>
# </li>
# <li class="list-item">
# <a data-code="id" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc&amp;lang=id" rel="nofollow">
#                                 Bahasa Indonesia
#                             </a>
# </li>
# <li class="list-item">
# <a data-code="fr" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc&amp;lang=fr" rel="nofollow">
#                                 Français
#                             </a>
# </li>
# <li class="list-item">
# <a data-code="es" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc&amp;lang=es" rel="nofollow">
#                                 Español
#                             </a>
# </li>
# <li class="list-item">
# <a data-code="zh-tw" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc&amp;lang=zh-tw" rel="nofollow">
#                                 繁體中文
#                             </a>
# </li>
# <li class="list-item">
# <a data-code="zh-cn" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc&amp;lang=zh-cn" rel="nofollow">
#                                 简体中文
#                             </a>
# </li>
# <li class="list-item">
# <a data-code="th" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc&amp;lang=th" rel="nofollow">
#                                 ภาษาไทย
#                             </a>
# </li>
# <li class="list-item">
# <a data-code="pt" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc&amp;lang=pt" rel="nofollow">
#                                 Português
#                             </a>
# </li>
# </ul>
# </li>
# <li class="list" data-type="currency">
# <h6 class="list-title">Currency Unit</h6>
# <ul class="list-content">
# <li class="list-item active">
# <a data-code="USD" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     USD - US Dollar
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="JPY" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     JPY - Japanese Yen
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="AUD" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     AUD - Australian Dollar
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="CAD" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     CAD - Canadian Dollar
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="EUR" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     EUR - Euro
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="ILS" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     ILS - Israeli Shekel
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="INR" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     INR - Indian Rupee
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="ZAR" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     ZAR - South African Rand
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="NZD" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     NZD - New Zealand Dollar
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="MXN" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     MXN - Mexican Peso
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="ARS" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     ARS - Argentine Peso
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="CLP" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     CLP - Chilean Peso
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="PEN" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     PEN - Peruvian Sol
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="CHF" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     CHF - Swiss Franc
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="BRL" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     BRL - Brazilian Real
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="RUB" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     RUB - Russian Ruble
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="SGD" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     SGD - Singapore Dollar
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="CNY" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     CNY - Chinese Yuan Renminbi
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="MYR" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     MYR - Malaysian Ringgit
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="HKD" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     HKD - Hong Kong Dollar
#                                 </a>
# </li>
# </ul>
# </li>
# <li class="list" data-type="areaUnit">
# <h6 class="list-title">Area Unit</h6>
# <ul class="list-content">
# <li class="list-item">
# <a data-code="Square meters" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     m<sup>2</sup> - Square Meter
#                                 </a>
# </li>
# <li class="list-item active">
# <a data-code="Square feet" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     sq ft - Square Foot
#                                 </a>
# </li>
# </ul>
# </li>
# <li class="list" data-type="distanceUnit">
# <h6 class="list-title">Distance Unit</h6>
# <ul class="list-content">
# <li class="list-item">
# <a data-code="Kilometers" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                             km - Kilometer
#                         </a>
# </li>
# <li class="list-item active">
# <a data-code="Miles" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                             mile - Mile
#                         </a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# </div>
# </header>
# </div>
# <div id="main">
# <div class="canvas top-bar unified-top-bar">
# <div class="country-selector-box">
# <div class="current-country">
# <i class="flag flag-32 flag-32-br"></i>
# <span class="name" title="Brazil">Brazil</span>
# <i class="arrow icon-caret-down"></i>
# <i class="arrow icon-caret-up"></i>
# </div>
# <div class="region-box">
# <i class="icon-caret-up"></i>
# <div class="title-bar">
# <span class="title">Select a country/region</span>
# <div class="close">
# <i class="icon-error"></i>
# </div>
# </div>
# <div class="region-list-box country-tab-wrap">
# <ul class="tab-nav">
# <li class="region-name active" id="region-americas">
# <span>Americas</span>
# </li>
# <li class="region-name" id="region-europe">
# <span>Europe</span>
# </li>
# <li class="region-name" id="region-asia">
# <span>Asia</span>
# </li>
# <li class="region-name" id="region-middle east">
# <span>Middle east</span>
# </li>
# <li class="region-name" id="region-africa">
# <span>Africa</span>
# </li>
# <li class="region-name" id="region-oceania">
# <span>Oceania</span>
# </li>
# </ul>
# <div class="tab-cont">
# <div class="region-list-box">
# <dl class="region-list americas active">
# <dt class="region-name" id="region-americas">Americas</dt>
# <dd class="region-child">
# <a class="item" href="/international/ag/">
# <i class="flag flag-24 flag-24-ag"></i>
# <span title="Antigua &amp; Barbuda">Antigua &amp; Barbuda</span>
# <i class="icon-arrow-right"></i>
# </a>
# </dd>
# <dd class="region-child">
# <a class="item" href="/international/ar/">
# <i class="flag flag-24 flag-24-ar"></i>
# <span title="Argentina">Argentina</span>
# <i class="icon-arrow-right"></i>
# </a>
# </dd>
# <dd class="region-child">
# <a class="item" href="/international/aw/">
# <i class="flag flag-24 flag-24-aw"></i>
# <span title="Aruba">Aruba</span>
# <i class="icon-arrow-right"></i>
# </a>
# </dd>
# <dd class="region-child">
# <a class="item" href="/international/bs/">
# <i class="flag flag-24 flag-24-bs"></i>
# <span title="Bahamas">Bahamas</span>
# <i class="icon-arrow-right"></i>
# </a>
# </dd>
# <dd class="region-child">
# <a class="item" href="/international/bb/">
# <i class="flag flag-24 flag-24-bb"></i>
# <span title="Barbados">Barbados</span>
# <i class="icon-arrow-right"></i>
# </a>
# </dd>
# <dd class="region-child">
# <a class="item" href="/international/bz/">
# <i class="flag flag-24 flag-24-bz"></i>
# <span title="Belize">Belize</span>
# <i class="icon-arrow-right"></i>
# </a>
# </dd>
# <dd class="region-child">
# <a class="item" href="/international/br/">
# <i class="flag flag-24 flag-24-br"></i>
# <span title="Brazil">Brazil</span>
# <i class="icon-arrow-right"></i>
# </a>
# </dd>
# <dd class="region-child">
# <a class="item" href="/international/vg/">
# <i class="flag flag-24 flag-24-vg"></i>
# <span title="British Virgin Islands">British Virgin Islands</span>
# <i class="icon-arrow-right"></i>
# </a>
# </dd>
# <dd class="region-child">
# <a class="item" href="/international/ca/">
# <i class="flag flag-24 flag-24-ca"></i>
# <span title="Canada">Canada</span>
# <i class="icon-arrow-right"></i>
# </a>
# </dd>
# <dd class="region-child">
# <a class="item" href="/international/ky/">
# <i class="flag flag-24 flag-24-ky"></i>
# <span title="Cayman Islands">Cayman Islands</span>
# <i class="icon-arrow-right"></i>
# </a>
# </dd>
# <dd class="region-child">
# <a class="item" href="/international/cl/">
# <i class="flag flag-24 flag-24-cl"></i>
# <span title="Chile">Chile</span>
# <i class="icon-arrow-right"></i>
# </a>
# </dd>
# <dd class="region-child">
# <a class="item" href="/international/co/">
# <i class="flag flag-24 flag-24-co"></i>
# <span title="Colombia">Colombia</span>
# <i class="icon-arrow-right"></i>
# </a>
# </dd>
# <dd class="region-child">
# <a class="item" href="/international/cr/">
# <i class="flag flag-24 flag-24-cr"></i>
# <span title="Costa Rica">Costa Rica</span>
# <i class="icon-arrow-right"></i>
# </a>
# </dd>
# <dd class="region-child">
# <a class="item" href="/international/cw/">
# <i class="flag flag-24 flag-24-cw"></i>
# <span title="Curaçao">Curaçao</span>
# <i class="icon-arrow-right"></i>
# </a>
# </dd>
# <dd class="region-child">
# <a class="item" href="/international/dm/">
# <i class="flag flag-24 flag-24-dm"></i>
# <span title="Dominica">Dominica</span>
# <i class="icon-arrow-right"></i>
# </a>
# </dd>
# <dd class="region-child">
# <a class="item" href="/international/do/">
# <i class="flag flag-24 flag-24-do"></i>
# <span title="Dominican Republic">Dominican Republic</span>
# <i class="icon-arrow-right"></i>
# </a>
# </dd>
# <dd class="region-child">
# <a class="item" href="/international/ec/">
# <i class="flag flag-24 flag-24-ec"></i>
# <span title="Ecuador">Ecuador</span>
# <i class="icon-arrow-right"></i>
# </a>
# </dd>
# <dd class="region-child">
# <a class="item" href="/international/sv/">
# <i class="flag flag-24 flag-24-sv"></i>
# <span title="El Salvador">El Salvador</span>
# <i class="icon-arrow-right"></i>
# </a>
# </dd>
# <dd class="region-child">
# <a class="item" href="/international/gf/">
# <i class="flag flag-24 flag-24-gf"></i>
# <span title="French Guiana">French Guiana</span>
# <i class="icon-arrow-right"></i>
# </a>
# </dd>
# <dd class="region-child">
# <a class="item" href="/international/gd/">
# <i class="flag flag-24 flag-24-gd"></i>
# <span title="Grenada">Grenada</span>
# <i class="icon-arrow-right"></i>
# </a>
# </dd>
# <dd class="region-child">
# <a class="item" href="/international/gp/">
# <i class="flag flag-24 flag-24-gp"></i>
# <span title="Guadeloupe">Guadeloupe</span>
# <i class="icon-arrow-right"></i>
# </a>
# </dd>
# <dd class="region-child">
# <a class="item" href="/international/gt/">
# <i class="flag flag-24 flag-24-gt"></i>
# <span title="Guatemala">Guatemala</span>
# <i class="icon-arrow-right"></i>
# </a>
# </dd>
# <dd class="region-child">
# <a class="item" href="/international/ht/">
# <i class="flag flag-24 flag-24-ht"></i>
# <span title="Haiti">Haiti</span>
# <i class="icon-arrow-right"></i>
# </a>
# </dd>
# <dd class="region-child">
# <a class="item" href="/international/hn/">
# <i class="flag flag-24 flag-24-hn"></i>
# <span title="Honduras">Honduras</span>
# <i class="icon-arrow-right"></i>
# </a>
# </dd>
# <dd class="region-child">
# <a class="item" href="/international/jm/">
# <i class="flag flag-24 flag-24-jm"></i>
# <span title="Jamaica">Jamaica</span>
# <i class="icon-arrow-right"></i>
# </a>
# </dd>
# <dd class="region-child">
# <a class="item" href="/international/mq/">
# <i class="flag flag-24 flag-24-mq"></i>
# <span title="Martinique">Martinique</span>
# <i class="icon-arrow-right"></i>
# </a>
# </dd>
# <dd class="region-child">
# <a class="item" href="/international/mx/">
# <i class="flag flag-24 flag-24-mx"></i>
# <span title="Mexico">Mexico</span>
# <i class="icon-arrow-right"></i>
# </a>
# </dd>
# <dd class="region-child">
# <a class="item" href="/international/ni/">
# <i class="flag flag-24 flag-24-ni"></i>
# <span title="Nicaragua">Nicaragua</span>
# <i class="icon-arrow-right"></i>
# </a>
# </dd>
# <dd class="region-child">
# <a class="item" href="/international/pa/">
# <i class="flag flag-24 flag-24-pa"></i>
# <span title="Panama">Panama</span>
# <i class="icon-arrow-right"></i>
# </a>
# </dd>
# <dd class="region-child">
# <a class="item" href="/international/py/">
# <i class="flag flag-24 flag-24-py"></i>
# <span title="Paraguay">Paraguay</span>
# <i class="icon-arrow-right"></i>
# </a>
# </dd>
# <dd class="region-child">
# <a class="item" href="/international/pe/">
# <i class="flag flag-24 flag-24-pe"></i>
# <span title="Peru">Peru</span>
# <i class="icon-arrow-right"></i>
# </a>
# </dd>
# <dd class="region-child">
# <a class="item" href="/international/pr/">
# <i class="flag flag-24 flag-24-pr"></i>
# <span title="Puerto Rico">Puerto Rico</span>
# <i class="icon-arrow-right"></i>
# </a>
# </dd>
# <dd class="region-child">
# <a class="item" href="/international/kn/">
# <i class="flag flag-24 flag-24-kn"></i>
# ...
#                                 简体中文
#                             </a>
# </li>
# <li class="list-item">
# <a data-code="th" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc&amp;lang=th" rel="nofollow">
#                                 ภาษาไทย
#                             </a>
# </li>
# <li class="list-item">
# <a data-code="pt" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc&amp;lang=pt" rel="nofollow">
#                                 Português
#                             </a>
# </li>
# </ul>
# </li>
# <li class="list" data-type="currency">
# <h6 class="list-title">Currency Unit</h6>
# <ul class="list-content">
# <li class="list-item active">
# <a data-code="USD" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     USD - US Dollar
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="JPY" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     JPY - Japanese Yen
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="AUD" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     AUD - Australian Dollar
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="CAD" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     CAD - Canadian Dollar
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="EUR" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     EUR - Euro
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="ILS" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     ILS - Israeli Shekel
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="INR" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     INR - Indian Rupee
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="ZAR" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     ZAR - South African Rand
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="NZD" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     NZD - New Zealand Dollar
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="MXN" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     MXN - Mexican Peso
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="ARS" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     ARS - Argentine Peso
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="CLP" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     CLP - Chilean Peso
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="PEN" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     PEN - Peruvian Sol
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="CHF" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     CHF - Swiss Franc
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="BRL" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     BRL - Brazilian Real
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="RUB" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     RUB - Russian Ruble
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="SGD" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     SGD - Singapore Dollar
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="CNY" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     CNY - Chinese Yuan Renminbi
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="MYR" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     MYR - Malaysian Ringgit
#                                 </a>
# </li>
# <li class="list-item">
# <a data-code="HKD" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     HKD - Hong Kong Dollar
#                                 </a>
# </li>
# </ul>
# </li>
# <li class="list" data-type="areaUnit">
# <h6 class="list-title">Area Unit</h6>
# <ul class="list-content">
# <li class="list-item">
# <a data-code="Square meters" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     m<sup>2</sup> - Square Meter
#                                 </a>
# </li>
# <li class="list-item active">
# <a data-code="Square feet" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                                     sq ft - Square Foot
#                                 </a>
# </li>
# </ul>
# </li>
# <li class="list" data-type="distanceUnit">
# <h6 class="list-title">Distance Unit</h6>
# <ul class="list-content">
# <li class="list-item">
# <a data-code="Kilometers" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                             km - Kilometer
#                         </a>
# </li>
# <li class="list-item active">
# <a data-code="Miles" href="/international/br/?searchtypes=house+apartment&amp;sort=price+desc" rel="nofollow">
#                             mile - Mile
#                         </a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="new-filter-entry desktop-hidden pad-visible phone-visible" id="new-filter-entry">
# <i class="icon-filters"></i>
# <span class="text">Filters</span>
# <span class="filter-count" id="filter-count"></span>
# </div>
# <footer>
# <div class="back-top phone-visible pad-visible desktop-hidden">
# <a href="#"><i class="icon-caret-up"></i><span class="text">Back to top</span></a>
# </div>
# <div class="contact-us-entry contact-us-entry-adjusted">
# <div class="canvas">
# <p>The world's largest source of international properties</p>
# <a class="btn" href="/international/contact-us/">Contact us</a>
# </div>
# </div>
# <div class="global-nav-footer" id="footer">
# <div class="footer-wrapper-social">
# <div class="container">
# <div class="footer-links-social">
# <ul class="global-nav-list-justified" id="footer-links-social">
# <li><a data-omtag="footer:social:tw" href="https://twitter.com/REALTORdotcom"><i class="svg-icon svg-icon-twitter"></i></a></li>
# <li><a data-omtag="footer:social:fb" href="https://www.facebook.com/realtor.com"><i class="svg-icon svg-icon-facebook"></i></a></li>
# <li><a data-omtag="footer:social:gp" href="https://plus.google.com/+REALTORdotcom/posts"><i class="svg-icon svg-icon-google-plus"></i></a></li>
# <li><a data-omtag="footer:social:pt" href="https://www.pinterest.com/realtordotcom/"><i class="svg-icon svg-icon-pinterest"></i></a></li>
# </ul>
# </div>
# <div class="footer-links-network">
# <a data-omtag="footer:partners:houseLogic" href="https://www.houselogic.com/?nicmp=hlim%26nichn=footerlink%26niseg=rc" id="footer-link-houselogic"> <i class="svg-logo svg-logo-houselogic"></i> </a>
# <a data-omtag="footer:partners:realtorUniv" href="http://www.realtoru.com/about/" id="footer-link-realtoru"> <i class="svg-logo svg-logo-realtoru"></i> </a>
# </div>
# </div>
# </div>
# <div class="footer-wrapper-links-main">
# <div class="container">
# <ul class="global-nav-list-horizontal" id="footer-links-primary">
# <li><a data-omtag="footer:corp:about" href="https://marketing.move.com/">About Us</a></li>
# <li><a data-omtag="footer:corp:careers" href="http://careers.move.com">Careers</a></li>
# <li><a data-omtag="footer:corp:feedback" href="#" id="global-nav-feedback">Feedback</a></li>
# <li><a data-omtag="footer:corp:mediaRoom" href="http://news.move.com/">Media Room</a></li>
# </ul>
# </div>
# </div>
# <div class="footer-wrapper-links-secondary">
# <div class="container">
# <ul class="global-nav-list-horizontal" id="footer-links-secondary">
# <li><a data-omtag="footer:corp:ad-choices" href="https://marketing.move.com/privacy-policy/#oba_anchor">Ad Choices</a></li>
# <li><a data-omtag="footer:corp:advertise" href="https://www.marketing.realtor.com/exhibit/">Advertise with us</a></li>
# <li><a data-omtag="footer:corp:agentSupport" href="https://support.realtor.com/#iid=rdc_hdr_realtors_support">Agent support</a></li>
# <li>
# <a data-original-title="" data-placement="top" data-popover-content="#footer-popover-products" href="javascript:void(0)" id="toggle-products" rel="popover" title=""> Products </a>
# <div class="global-nav-hide footer-popover-content" id="footer-popover-products">
# <ul class="global-nav-list-unstyled">
# <li><a data-omtag="footer:products:listHub" href="https://www.listhub.com/home.html">ListHub</a></li>
# <li><a data-omtag="footer:products:topProducer" href="https://www.topproducer.com/">Top Producer</a></li>
# <li><a data-omtag="footer:products:fiveStreet" href="https://www.fivestreet.com/">FiveStreet</a></li>
# <li><a data-omtag="footer:products:reesio" href="https://www.reesio.com/">Reesio</a></li>
# <li><a data-omtag="footer:partners:move" href="https://www.move.com/">Move.com</a></li>
# <li><a data-omtag="footer:partners:relocation" href="http://www.relocation.com/">Relocation</a></li>
# <li><a data-omtag="footer:partners:moving" href="http://www.moving.com/">Moving.com</a></li>
# <li><a data-omtag="footer:network:international" href="https://www.realtor.com/international/">International</a></li>
# <li><a data-omtag="footer:network:commerical" href="http://commercialsearch.realtor.com/">Commercial</a></li>
# <li><a data-omtag="footer:network:senior" href="http://www.seniorhousingnet.com/">SeniorHousingNet.com</a></li>
# <li><a data-omtag="footer:network:doorsteps" href="https://www.doorsteps.com/">Doorsteps</a></li>
# <li><a data-omtag="footer:network:remodelista" href="https://www.remodelista.com/?utm_source=realtor&amp;utm_medium=top_nav&amp;utm_campaign=rdc_nav/">Remodelista</a></li>
# <li><a data-omtag="footer:network:gardenista" href="https://www.gardenista.com/?utm_source=realtor&amp;utm_medium=top_nav&amp;utm_campaign=rdc_nav/">Gardenista</a></li>
# </ul>
# </div>
# </li>
# <li>
# <a data-original-title="" data-placement="top" data-popover-content="#footer-popover-newscorp" href="javascript:void(0)" id="toggle-newscorp" rel="popover" title="">News Corp</a>
# <div class="global-nav-hide footer-popover-content" id="footer-popover-newscorp">
# <ul class="global-nav-list-unstyled">
# <li><a data-omtag="footer-menu:nc:network:barrons" href="http://www.barrons.com">Barron’s</a></li>
# <li><a data-omtag="footer-menu:nc:network:checkout-51" href="https://www.checkout51.com">Checkout 51</a></li>
# <li><a data-omtag="footer-menu:nc:network:financial-news" href="https://www.fnlondon.com">Financial News</a></li>
# <li><a data-omtag="footer-menu:nc:network:harper-collins" href="https://www.harpercollins.com/">Harper Collins</a></li>
# <li><a data-omtag="footer-menu:nc:network:mansion-global" href="https://www.mansionglobal.com/">Mansion Global</a></li>
# <li><a data-omtag="footer-menu:nc:network:market-watch" href="http://www.marketwatch.com/">Market Watch</a></li>
# <li><a data-omtag="footer-menu:nc:network:new-york-post" href="https://nypost.com/">New York Post</a></li>
# <li><a data-omtag="footer-menu:nc:network:rea" href="https://www.rea-group.com/">REA</a></li>
# <li><a data-omtag="footer-menu:nc:network:storyful" href="https://storyful.com/">Storyful</a></li>
# <li><a data-omtag="footer-menu:nc:network:wall-street-journal" href="https://www.wsj.com">Wall Street Journal</a></li>
# </ul>
# </div>
# </li>
# <li>
# <a data-omtag="footer:corp:privacy" href="https://marketing.move.com/privacy-policy/">Privacy</a> / <a data-omtag="footer:corp:terms" href="https://marketing.move.com/terms-of-service/">Terms</a>
# </li>
# <li><a data-omtag="footer:corp:sitemap" href="https://www.realtor.com/sitemap">Sitemap</a></li>
# </ul>
# </div>
# </div>
# <div class="footer-wrapper-copyright">
# <div class="container">
# <p id="footer-copyright">
#                         ©1995-2022 <a data-omtag="footer:corp:nar" href="http://www.realtor.org">National Association of REALTORS<sup>®</sup></a> and <a href="http://www.move.com/">Move, Inc.</a> All rights reserved.<br/>
#                         realtor.com<sup>®</sup> is the official site of the National Association of REALTORS<sup>®</sup> and is operated by Move, Inc., a subsidiary of News Corp.
#                     </p>
# </div>
# </div>
# </div>
# </footer>
# <script defer="" src="//s4.rea.global/js/page/results-c4b9d4b7b5a0a1e9.js" type="text/javascript"></script>
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"errorBeacon":"bam.nr-data.net","licenseKey":"aebbba13a5","agent":"","beacon":"bam.nr-data.net","applicationTime":319,"applicationID":"23589959","transactionName":"NFZSZUIHDEdSBhVaVw0cY0FCDwxTcAoPR0oMX1xUQkkRUVIXAlsYS3R1ZRk=","queueTime":0}</script>
# <script>
#
#         window.adsConfig = eval('( {"countryLocation":"br","site":"rea_global","language":"en","area":"buy.resultslist","proptype":"house","client":"realtor"} )');
#
#
# </script>
# <!--needs to be at the end of closing-->
# <script type="text/javascript">
#             if (typeof(_satellite) !== 'undefined' && typeof _satellite.pageBottom === 'function'){
#                 _satellite.pageBottom();
#             }
#         </script>
# <script async="" type="text/javascript">
#         typeof window.tealiumData !== 'undefined' ? window.aTrack(Object.assign({}, window.tealiumData.view)) : window.aTrack({});
#     </script>
# <script type="application/ld+json">{"url":"https://www.realtor.com/international/br/?searchtypes=house+apartment&sort=price+desc","name":"Property for Sale in Brazil - realtor.com","description":"Find Property for sale in Brazil. Search for real estate and find the latest listings of Brazil Property for sale.","breadCrumb":{"itemListElement":[{"position":1,"item":{"id":"https://www.realtor.com/international/","url":"https://www.realtor.com/international/","name":"International","@type":"WebPage"},"@type":"ListItem"},{"position":2,"item":{"id":"https://www.realtor.com/international/br/?sort=price+desc","url":"https://www.realtor.com/international/br/?sort=price+desc","name":"Brazil","@type":"WebPage"},"@type":"ListItem"}],"@type":"BreadcrumbList"},"mainEntity":[{"name":"Property for Sale in Brazil","description":"Find Property for sale in Brazil. Search for real estate and find the latest listings of Brazil Property for sale.","image":"https://s1.rea.global/img/raw/realtor/br/deb543c12244215a7f87aa3ae609670d.jpg","offers":{"@type":"AggregateOffer","url":"https://www.realtor.com/international/br/?searchtypes=house+apartment&sort=price+desc","lowPrice":"3.400064168E7","highPrice":"6.8E8","priceCurrency":"BRL","offerCount":"20"},"brand":{"name":"https://www.realtor.com"},"sku":"https://www.realtor.com/international/br/?searchtypes=house+apartment&sort=price+desc","mpn":"https://www.realtor.com","@type":"Product"}],"@context":"https://schema.org","@type":"RealEstateListing"}</script>
# </body>
# </html>

# %%
price_list = r.find_all('p','listing-price specified')
#print(price_list)

for price in price_list:
    price = price.find('strong').text
    print(price)
# Out:
#
#                 BRL R$680,000,000
#
#
#
#
#                 BRL R$84,502,239
#
#
#
#
#                 BRL R$80,050,498
#
#
#
#
#                 BRL R$80,000,000
#
#
#
#
#                 BRL R$67,802,760
#
#
#
#
#                 BRL R$59,933,368
#
#
#
#
#                 BRL R$58,286,814
#
#
#
#
#                 BRL R$55,000,000
#
#
#
#
#                 BRL R$50,234,843
#
#
#
#
#                 BRL R$48,087,441
#
#
#
#
#                 BRL R$46,299,136
#
#
#
#
#                 BRL R$46,131,658
#
#
#
#
#                 BRL R$44,015,996
#
#
#
#
#                 BRL R$41,116,331
#
#
#
#
#                 BRL R$39,500,000
#
#
#
#
#                 BRL R$38,857,876
#
#
#
#
#                 BRL R$36,840,748
#
#
#
#
#                 BRL R$34,843,898
#
#
#
#
#                 BRL R$34,000,642
#
#
#
#
#                 BRL R$34,000,642

# %%
garage_list = r.find_all('li','Bedrooms')
#print(price_list)

for garage in garage_list:
    garage = garage.find('strong').text
    print(garage)

# %%
price_list[0].contents[1].text
# Out:
# 'Venda R$ 11.700.000,00'

# %%
type_list = site.find_all('div','badges')
#print(price_list)

for type_ in type_list:
    type_ = type_.find('span').text
    print(type_)
# Out:
# Terreno/Lote Comercial
# Apartamento
# Cobertura Duplex
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Cobertura Duplex
# Apartamento
# Casa em Condomínio
# Casa em Condomínio
# Apartamento
# Sobrado em Condomínio
# Sobrado em Condomínio
# Casa em Condomínio
# Apartamento
# Apartamento
# Terreno/Lote Residencial
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Casa em Condomínio
# Sala Comercial
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Casa em Condomínio
# Apartamento
# Sala Comercial
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Sobrado em Condomínio
# Terreno/Lote Comercial
# Sobrado em Condomínio
# Casa em Condomínio
# Sobrado em Condomínio
# Sobrado
# Apartamento
# Apartamento
# Apartamento
# Casa em Condomínio
# Apartamento
# Apartamento
# Apartamento
# Casa
# Cobertura Duplex
# Apartamento
# Casa em Condomínio
# Apartamento Garden
# Casa em Condomínio
# Casa em Condomínio
# Casa em Condomínio
# Sobrado
# Casa em Condomínio
# Apartamento
# Cobertura Triplex
# Casa em Condomínio
# Cobertura Duplex
# Apartamento
# Apartamento
# Cobertura Duplex
# Terreno/Lote Residencial
# Terreno/Lote Residencial
# Casa em Condomínio
# Cobertura Duplex
# Sobrado
# Apartamento
# Apartamento
# Cobertura Duplex
# Loja
# Apartamento
# Apartamento
# Cobertura Duplex
# Apartamento
# Apartamento
# Apartamento
# Loja
# Cobertura Duplex
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Studio
# Studio
# Sala Comercial
# Sala Comercial
# Apartamento
# Cobertura Duplex
# Apartamento
# Apartamento
# Apartamento
# Barracão
# Apartamento
# Casa
# Apartamento
# Apartamento
# Cobertura Duplex
# Sobrado em Condomínio
# Sobrado em Condomínio
# Apartamento
# Sala Comercial
# Apartamento
# Apartamento
# Cobertura Duplex
# Casa em Condomínio
# Casa em Condomínio
# Apartamento
# Apartamento
# Apartamento Duplex
# Apartamento
# Apartamento
# Apartamento
# Cobertura Duplex
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Sobrado em Condomínio
# Apartamento
# Sobrado em Condomínio
# Sobrado em Condomínio
# Sobrado em Condomínio
# Sobrado em Condomínio
# Apartamento
# Apartamento
# Apartamento
# Cobertura Duplex
# Apartamento
# Apartamento
# Sobrado em Condomínio
# Apartamento
# Barracão
# Apartamento
# Cobertura Duplex
# Apartamento
# Sala Comercial
# Apartamento Garden
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Terreno em Condomínio
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Sobrado
# Sobrado
# Apartamento
# Apartamento
# Casa
# Apartamento Duplex
# Apartamento Duplex
# Sobrado
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Sobrado
# Sobrado
# Sobrado em Condomínio
# Sobrado em Condomínio
# Casa
# Apartamento
# Apartamento
# Casa
# Casa em Condomínio
# Casa em Condomínio
# Apartamento Garden
# Cobertura Triplex
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Sobrado
# Apartamento
# Sobrado
# Apartamento
# Casa em Condomínio
# Sobrado em Condomínio
# Apartamento Garden
# Casa em Condomínio
# Apartamento
# Apartamento Garden
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Sobrado em Condomínio
# Sobrado
# Sobrado
# Sobrado em Condomínio
# Apartamento
# Apartamento
# Apartamento
# Casa
# Casa em Condomínio
# Casa em Condomínio
# Casa em Condomínio
# Casa em Condomínio
# Apartamento
# Casa em Condomínio
# Casa em Condomínio
# Casa em Condomínio
# Apartamento
# Apartamento
# Casa em Condomínio
# Apartamento
# Casa em Condomínio
# Casa em Condomínio
# Apartamento
# Apartamento
# Casa em Condomínio
# Casa em Condomínio
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento Garden
# Sala Comercial
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Sobrado
# Apartamento
# Apartamento Garden
# Cobertura Horizontal
# Apartamento
# Apartamento
# Casa em Condomínio
# Cobertura Duplex
# Casa em Condomínio
# Sala Comercial
# Cobertura Duplex
# Apartamento
# Apartamento
# Apartamento
# Sobrado em Condomínio
# Sobrado em Condomínio
# Sobrado
# Apartamento
# Apartamento
# Apartamento
# Sobrado
# Apartamento
# Apartamento
# Casa em Condomínio
# Apartamento
# Apartamento
# Apartamento
# Casa em Condomínio
# Casa
# Apartamento
# Apartamento
# Casa
# Apartamento
# Casa em Condomínio
# Apartamento
# Terreno em Condomínio
# Apartamento
# Sobrado
# Apartamento
# Casa em Condomínio
# Terreno em Condomínio
# Sobrado
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Sobrado
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Sobrado
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Cobertura Duplex
# Apartamento
# Cobertura Duplex
# Apartamento
# Terreno/Lote Residencial
# Terreno em Condomínio
# Terreno em Condomínio
# Apartamento
# Apartamento
# Apartamento
# Apartamento
# Terreno em Condomínio
# Apartamento
# Apartamento
# Sobrado em Condomínio
# Cobertura Duplex
# Apartamento
# Sobrado
# Apartamento

# %%
list_spec = []

spec_list_num = site.find_all('div','spec-item')
#print(price_list)

for spec in spec_list_num:
    spec_num = spec.find('span').text.replace(' quartos','').replace(' suítes','').replace(' m²','').replace(' banheiros','').replace(' garagens','').replace('.','').replace(' suíte','').replace(' banheiro','').replace(' garagem','').replace(' quarto','')
    list_spec.append(spec_num)

list_spec
# Out:
# ['27000,00',
#  '4',
#  '4',
#  '5',
#  '4',
#  '315,11',
#  '4',
#  '4',
#  '5',
#  '4',
#  '371,00',
#  '3',
#  '3',
#  '4',
#  '3',
#  '164,00',
#  '3',
#  '3',
#  '5',
#  '2',
#  '176,00',
#  '3',
#  '3',
#  '3',
#  '4',
#  '309,19',
#  '4',
#  '4',
#  '6',
#  '3',
#  '264,33',
#  '4',
#  '4',
#  '5',
#  '4',
#  '344,79',
#  '3',
#  '3',
#  '4',
#  '4',
#  '185,00',
#  '4',
#  '2',
#  '4',
#  '4',
#  '298,00',
#  '4',
#  '4',
#  '6',
#  '3',
#  '466,00',
#  '3',
#  '1',
#  '2',
#  '2',
#  '105,00',
#  '4',
#  '1',
#  '3',
#  '2',
#  '192,40',
#  '4',
#  '1',
#  '3',
#  '2',
#  '173,99',
#  '4',
#  '2',
#  '4',
#  '2',
#  '354,00',
#  '2',
#  '1',
#  '2',
#  '1',
#  '59,62',
#  '3',
#  '1',
#  '3',
#  '2',
#  '106,00',
#  '575,90',
#  '2',
#  '1',
#  '2',
#  '1',
#  '70,57',
#  '3',
#  '1',
#  '2',
#  '2',
#  '88,22',
#  '2',
#  '1',
#  '1',
#  '53,91',
#  '2',
#  '2',
#  '3',
#  '3',
#  '91,00',
#  '3',
#  '1',
#  '3',
#  '2',
#  '93,00',
#  '3',
#  '3',
#  '4',
#  '2',
#  '184,00',
#  '1',
#  '28,00',
#  '2',
#  '1',
#  '2',
#  '2',
#  '72,00',
#  '3',
#  '1',
#  '3',
#  '1',
#  '107,00',
#  '3',
#  '1',
#  '2',
#  '2',
#  '111,00',
#  '2',
#  '1',
#  '1',
#  '51,00',
#  '2',
#  '1',
#  '2',
#  '1',
#  '56,00',
#  '3',
#  '1',
#  '2',
#  '2',
#  '71,00',
#  '3',
#  '1',
#  '2',
#  '2',
#  '80,58',
#  '3',
#  '1',
#  '3',
#  '2',
#  '269,00',
#  '4',
#  '3',
#  '3',
#  '4',
#  '342,07',
#  '1',
#  '68,78',
#  '3',
#  '3',
#  '4',
#  '2',
#  '151,37',
#  '3',
#  '1',
#  '2',
#  '1',
#  '88,00',
#  '3',
#  '3',
#  '4',
#  '2',
#  '121,92',
#  '2',
#  '2',
#  '3',
#  '2',
#  '3',
#  '1',
#  '3',
#  '2',
#  '163,00',
#  '27000,00',
#  '3',
#  '1',
#  '3',
#  '2',
#  '168,00',
#  '3',
#  '2',
#  '2',
#  '91,00',
#  '2',
#  '1',
#  '1',
#  '2',
#  '77,92',
#  '3',
#  '1',
#  '2',
#  '2',
#  '154,00',
#  '2',
#  '2',
#  '2',
#  '2',
#  '85,16',
#  '3',
#  '3',
#  '5',
#  '3',
#  '250,00',
#  '3',
#  '1',
#  '2',
#  '1',
#  '67,00',
#  '5',
#  '3',
#  '6',
#  '4',
#  '294,00',
#  '1',
#  '1',
#  '1',
#  '49,00',
#  '3',
#  '1',
#  '2',
#  '1',
#  '74,00',
#  '4',
#  '2',
#  '4',
#  '2',
#  '166,00',
#  '5',
#  '1',
#  '2',
#  '5',
#  '220,75',
#  '3',
#  '3',
#  '3',
#  '3',
#  '227,00',
#  '2',
#  '1',
#  '1',
#  '47,86',
#  '3',
#  '2',
#  '4',
#  '1',
#  '176,00',
#  '1',
#  '1',
#  '1',
#  '35,00',
#  '4',
#  '4',
#  '5',
#  '2',
#  '369,00',
#  '3',
#  '2',
#  '3',
#  '2',
#  '171,00',
#  '3',
#  '2',
#  '3',
#  '3',
#  '195,00',
#  '3',
#  '1',
#  '2',
#  '2',
#  '199,00',
#  '3',
#  '1',
#  '2',
#  '2',
#  '147,00',
#  '3',
#  '3',
#  '5',
#  '4',
#  '247,00',
#  '4',
#  '2',
#  '4',
#  '4',
#  '240,00',
#  '3',
#  '1',
#  '3',
#  '3',
#  '258,00',
#  '3',
#  '3',
#  '4',
#  '4',
#  '173,00',
#  '3',
#  '3',
#  '5',
#  '3',
#  '153,00',
#  '3',
#  '3',
#  '3',
#  '3',
#  '141,06',
#  '2',
#  '1',
#  '2',
#  '3',
#  '95,00',
#  '900,00',
#  '777,00',
#  '3',
#  '1',
#  '2',
#  '2',
#  '90,00',
#  '4',
#  '2',
#  '5',
#  '3',
#  '218,00',
#  '3',
#  '1',
#  '2',
#  '2',
#  '120,00',
#  '3',
#  '3',
#  '2',
#  '3',
#  '293,58',
#  '3',
#  '1',
#  '2',
#  '2',
#  '97,72',
#  '4',
#  '4',
#  '5',
#  '4',
#  '344,79',
#  '15',
#  '368,00',
#  '2',
#  '1',
#  '2',
#  '2',
#  '67,67',
#  '2',
#  '2',
#  '2',
#  '2',
#  '102,79',
#  '3',
#  '3',
#  '3',
#  '3',
#  '227,00',
#  '3',
#  '1',
#  '2',
#  '1',
#  '87,00',
#  '3',
#  '1',
#  '1',
#  '2',
#  '97,00',
#  '3',
#  '1',
#  '2',
#  '1',
#  '182,00',
#  '300,17',
#  '2',
#  '2',
#  '3',
#  '2',
#  '256,25',
#  '2',
#  '1',
#  '2',
#  '1',
#  '56,48',
#  '1',
#  '1',
#  '1',
#  '35,82',
#  '1',
#  '1',
#  '1',
#  '45,27',
#  '2',
#  '53,27',
#  '2',
#  '1',
#  '49,65',
#  '1',
#  '1',
#  '23,32',
#  '1',
#  '1',
#  '29,30',
#  '370,93',
#  '1',
#  '80,00',
#  '3',
#  '3',
#  '6',
#  '4',
#  '257,00',
#  '3',
#  '2',
#  '3',
#  '2',
#  '136,00',
#  '2',
#  '1',
#  '1',
#  '54,00',
#  '1',
#  '1',
#  '34,00',
#  '3',
#  '3',
#  '5',
#  '4',
#  '227,00',
#  '3',
#  '50',
#  '640,00',
#  '3',
#  '1',
#  '2',
#  '2',
#  '117,00',
#  '4',
#  '1',
#  '3',
#  '4',
#  '435,00',
#  '3',
#  '1',
#  '4',
#  '2',
#  '128,00',
#  '3',
#  '1',
#  '3',
#  '1',
#  '182,00',
#  '3',
#  '3',
#  '4',
#  '3',
#  '188,00',
#  '3',
#  '1',
#  '3',
#  '2',
#  '91,58',
#  '3',
#  '1',
#  '4',
#  '2',
#  '150,02',
#  '2',
#  '1',
#  '2',
#  '1',
#  '70,13',
#  '1',
#  '38,48',
#  '3',
#  '3',
#  '3',
#  '4',
#  '309,19',
#  '3',
#  '3',
#  '3',
#  '3',
#  '212,71',
#  '4',
#  '4',
#  '7',
#  '6',
#  '513,86',
#  '3',
#  '1',
#  '3',
#  '2',
#  '170,00',
#  '3',
#  '3',
#  '6',
#  '4',
#  '430,00',
#  '3',
#  '3',
#  '5',
#  '2',
#  '155,00',
#  '2',
#  '2',
#  '3',
#  '2',
#  '103,00',
#  '2',
#  '2',
#  '3',
#  '2',
#  '103,00',
#  '4',
#  '2',
#  '2',
#  '120,00',
#  '2',
#  '1',
#  '1',
#  '1',
#  '63,00',
#  '2',
#  '1',
#  '2',
#  '2',
#  '70,00',
#  '4',
#  '4',
#  '5',
#  '2',
#  '331,80',
#  '4',
#  '4',
#  '5',
#  '3',
#  '151,00',
#  '4',
#  '4',
#  '5',
#  '2',
#  '144,00',
#  '3',
#  '3',
#  '4',
#  '2',
#  '138,00',
#  '3',
#  '3',
#  '4',
#  '2',
#  '127,00',
#  '4',
#  '4',
#  '5',
#  '4',
#  '315,11',
#  '2',
#  '1',
#  '2',
#  '2',
#  '75,00',
#  '2',
#  '1',
#  '2',
#  '1',
#  '54,00',
#  '2',
#  '1',
#  '1',
#  '53,91',
#  '3',
#  '1',
#  '2',
#  '2',
#  '154,00',
#  '3',
#  '1',
#  '3',
#  '2',
#  '131,00',
#  '1',
#  '1',
#  '1',
#  '47,00',
#  '3',
#  '1',
#  '3',
#  '2',
#  '119,00',
#  '3',
#  '1',
#  '3',
#  '2',
#  '119,00',
#  '3',
#  '1',
#  '3',
#  '2',
#  '195,00',
#  '3',
#  '1',
#  '3',
#  '2',
#  '131,00',
#  '3',
#  '3',
#  '4',
#  '2',
#  '120,40',
#  '3',
#  '1',
#  '2',
#  '1',
#  '61,00',
#  '2',
#  '1',
#  '2',
#  '1',
#  '68,00',
#  '3',
#  '3',
#  '5',
#  '4',
#  '207,00',
#  '3',
#  '1',
#  '2',
#  '1',
#  '79,00',
#  '3',
#  '1',
#  '2',
#  '1',
#  '87,00',
#  '3',
#  '1',
#  '3',
#  '2',
#  '108,92',
#  '2',
#  '1',
#  '2',
#  '1',
#  '71,00',
#  '3',
#  '10',
#  '600,00',
#  '2',
#  '1',
#  '1',
#  '1',
#  '66,00',
#  '2',
#  '2',
#  '3',
#  '2',
#  '126,00',
#  '1',
#  '1',
#  '1',
#  '32,00',
#  '1',
#  '38,00',
#  '1',
#  '1',
#  '72,00',
#  '2',
#  '1',
#  '2',
#  '2',
#  '73,00',
#  '4',
#  '1',
#  '2',
#  '2',
#  '120,00',
#  '2',
#  '1',
#  '3',
#  '2',
#  '75,00',
#  '1',
#  '1',
#  '2',
#  '1',
#  '49,00',
#  '3',
#  '3',
#  '4',
#  '3',
#  '160,00',
#  '2',
#  '1',
#  '2',
#  '2',
#  '91,00',
#  '2',
#  '1',
#  '2',
#  '1',
#  '68,00',
#  '754,00',
#  '2',
#  '1',
#  '2',
#  '1',
#  '3',
#  '3',
#  '4',
#  '3',
#  '153,00',
#  '1',
#  '1',
#  '18,00',
#  '1',
#  '1',
#  '34,00',
#  '3',
#  '3',
#  '4',
#  '3',
#  '160,00',
#  '3',
#  '3',
#  '3',
#  '2',
#  '138,88',
#  '3',
#  '3',
#  '3',
#  '2',
#  '138,00',
#  '3',
#  '3',
#  '4',
#  '2',
#  '160,00',
#  '3',
#  '1',
#  '3',
#  '2',
#  '103,00',
#  '3',
#  '1',
#  '3',
#  '1',
#  '156,00',
#  '4',
#  '2',
#  '4',
#  '3',
#  '226,00',
#  '4',
#  '2',
#  '4',
#  '3',
#  '226,00',
#  '3',
#  '1',
#  '3',
#  '2',
#  '155,00',
#  '3',
#  '3',
#  '4',
#  '2',
#  '119,00',
#  '3',
#  '1',
#  '2',
#  '1',
#  '86,00',
#  '3',
#  '1',
#  '2',
#  '1',
#  '106,00',
#  '3',
#  '2',
#  '1',
#  '99,00',
#  '3',
#  '3',
#  '3',
#  '2',
#  '136,46',
#  '3',
#  '1',
#  '2',
#  '2',
#  '97,00',
#  '3',
#  '1',
#  '3',
#  '2',
#  '97,00',
#  '2',
#  '1',
#  '2',
#  '1',
#  '80,00',
#  '3',
#  '1',
#  '3',
#  '1',
#  '119,00',
#  '3',
#  '1',
#  '3',
#  '1',
#  '111,00',
#  '4',
#  '1',
#  '4',
#  '2',
#  '122,00',
#  '4',
#  '1',
#  '4',
#  '2',
#  '123,00',
#  '4',
#  '1',
#  '4',
#  '2',
#  '123,00',
#  '3',
#  '1',
#  '3',
#  '2',
#  '106,00',
#  '3',
#  '1',
#  '3',
#  '2',
#  '106,00',
#  '3',
#  '1',
#  '5',
#  '2',
#  '236,00',
#  '3',
#  '1',
#  '5',
#  '2',
#  '236,00',
#  '4',
#  '2',
#  '3',
#  '4',
#  '178,00',
#  '3',
#  '1',
#  '2',
#  '2',
#  '71,32',
#  '1',
#  '1',
#  '2',
#  '1',
#  '99,00',
#  '3',
#  '1',
#  '3',
#  '2',
#  '153,00',
#  '5',
#  '2',
#  '5',
#  '10',
#  '650,00',
#  '4',
#  '4',
#  '5',
#  '3',
#  '295,00',
#  '3',
#  '1',
#  '2',
#  '1',
#  '3',
#  '3',
#  '5',
#  '194,00',
#  '1',
#  '1',
#  '33,00',
#  '3',
#  '1',
#  '1',
#  '60,15',
#  '4',
#  '4',
#  '6',
#  '4',
#  '260,00',
#  '2',
#  '1',
#  '2',
#  '2',
#  '3',
#  '1',
#  '2',
#  '2',
#  '142,00',
#  '1',
#  '1',
#  '41,00',
#  '3',
#  '1',
#  '2',
#  '2',
#  '142,00',
#  '2',
#  '1',
#  '3',
#  '1',
#  '102,34',
#  '3',
#  '1',
#  '3',
#  '2',
#  '210,00',
#  '3',
#  '1',
#  '3',
#  '2',
#  '170,00',
#  '2',
#  '1',
#  '2',
#  '2',
#  '113,00',
#  '3',
#  '1',
#  '4',
#  '2',
#  '140,00',
#  '4',
#  '2',
#  '4',
#  '1',
#  '184,00',
#  '1',
#  '1',
#  '31,00',
#  '2',
#  '1',
#  '2',
#  '1',
#  '68,00',
#  '4',
#  '4',
#  '5',
#  '3',
#  '284,00',
#  '2',
#  '1',
#  '1',
#  '55,00',
#  '3',
#  '1',
#  '2',
#  '1',
#  '104,00',
#  '4',
#  '2',
#  '5',
#  '1',
#  '255,00',
#  '3',
#  '2',
#  '3',
#  '2',
#  '103,00',
#  '3',
#  '1',
#  '2',
#  '1',
#  '65,00',
#  '2',
#  '1',
#  '2',
#  '1',
#  '70,00',
#  '3',
#  '1',
#  '3',
#  ...]

# %%
x = list_spec
mat = []
while x != []:
  mat.append(x[:5])
  x = x[5:]
df = pd.DataFrame(mat, columns=['m²','quarto','suíte','banheiro','garagem'])
df
# Out:
#            m² quarto suíte banheiro garagem
# 0    27000,00      4     4        5       4
# 1      315,11      4     4        5       4
# 2      371,00      3     3        4       3
# 3      164,00      3     3        5       2
# 4      176,00      3     3        3       4
# ..        ...    ...   ...      ...     ...
# 318     87,00      3     3        4       4
# 319    255,00      2     2        3       2
# 320     84,00      3     1        2       4
# 321    198,00      2     1        2       1
# 322     63,00   None  None     None    None
#
# [323 rows x 5 columns]

# %%
# determining the name of the file
file_name = 'specs.xlsx'
  
# saving the excel
df.to_excel(file_name)

# %%
list_ = []
spec_list_num = site.find_all('div','spec-item')
#print(price_list)

for spec in spec_list_num:
    spec_num = spec.find('span').text.replace(' ',' - ')
    list_.append(spec_num)

list_
# Out:
# ['27.000,00 - m²',
#  '4 - quartos',
#  '4 - suítes',
#  '5 - banheiros',
#  '4 - garagens',
#  '315,11 - m²',
#  '4 - quartos',
#  '4 - suítes',
#  '5 - banheiros',
#  '4 - garagens',
#  '371,00 - m²',
#  '3 - quartos',
#  '3 - suítes',
#  '4 - banheiros',
#  '3 - garagens',
#  '164,00 - m²',
#  '3 - quartos',
#  '3 - suítes',
#  '5 - banheiros',
#  '2 - garagens',
#  '176,00 - m²',
#  '3 - quartos',
#  '3 - suítes',
#  '3 - banheiros',
#  '4 - garagens',
#  '309,19 - m²',
#  '4 - quartos',
#  '4 - suítes',
#  '6 - banheiros',
#  '3 - garagens',
#  '264,33 - m²',
#  '4 - quartos',
#  '4 - suítes',
#  '5 - banheiros',
#  '4 - garagens',
#  '344,79 - m²',
#  '3 - quartos',
#  '3 - suítes',
#  '4 - banheiros',
#  '4 - garagens',
#  '185,00 - m²',
#  '4 - quartos',
#  '2 - suítes',
#  '4 - banheiros',
#  '4 - garagens',
#  '298,00 - m²',
#  '4 - quartos',
#  '4 - suítes',
#  '6 - banheiros',
#  '3 - garagens',
#  '466,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '2 - garagens',
#  '105,00 - m²',
#  '4 - quartos',
#  '1 - suíte',
#  '3 - banheiros',
#  '2 - garagens',
#  '192,40 - m²',
#  '4 - quartos',
#  '1 - suíte',
#  '3 - banheiros',
#  '2 - garagens',
#  '173,99 - m²',
#  '4 - quartos',
#  '2 - suítes',
#  '4 - banheiros',
#  '2 - garagens',
#  '354,00 - m²',
#  '2 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '1 - garagem',
#  '59,62 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '3 - banheiros',
#  '2 - garagens',
#  '106,00 - m²',
#  '575,90 - m²',
#  '2 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '1 - garagem',
#  '70,57 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '2 - garagens',
#  '88,22 - m²',
#  '2 - quartos',
#  '1 - banheiro',
#  '1 - garagem',
#  '53,91 - m²',
#  '2 - quartos',
#  '2 - suítes',
#  '3 - banheiros',
#  '3 - garagens',
#  '91,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '3 - banheiros',
#  '2 - garagens',
#  '93,00 - m²',
#  '3 - quartos',
#  '3 - suítes',
#  '4 - banheiros',
#  '2 - garagens',
#  '184,00 - m²',
#  '1 - banheiro',
#  '28,00 - m²',
#  '2 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '2 - garagens',
#  '72,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '3 - banheiros',
#  '1 - garagem',
#  '107,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '2 - garagens',
#  '111,00 - m²',
#  '2 - quartos',
#  '1 - banheiro',
#  '1 - garagem',
#  '51,00 - m²',
#  '2 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '1 - garagem',
#  '56,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '2 - garagens',
#  '71,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '2 - garagens',
#  '80,58 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '3 - banheiros',
#  '2 - garagens',
#  '269,00 - m²',
#  '4 - quartos',
#  '3 - suítes',
#  '3 - banheiros',
#  '4 - garagens',
#  '342,07 - m²',
#  '1 - banheiro',
#  '68,78 - m²',
#  '3 - quartos',
#  '3 - suítes',
#  '4 - banheiros',
#  '2 - garagens',
#  '151,37 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '1 - garagem',
#  '88,00 - m²',
#  '3 - quartos',
#  '3 - suítes',
#  '4 - banheiros',
#  '2 - garagens',
#  '121,92 - m²',
#  '2 - quartos',
#  '2 - suítes',
#  '3 - banheiros',
#  '2 - garagens',
#  '3 - quartos',
#  '1 - suíte',
#  '3 - banheiros',
#  '2 - garagens',
#  '163,00 - m²',
#  '27.000,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '3 - banheiros',
#  '2 - garagens',
#  '168,00 - m²',
#  '3 - quartos',
#  '2 - banheiros',
#  '2 - garagens',
#  '91,00 - m²',
#  '2 - quartos',
#  '1 - suíte',
#  '1 - banheiro',
#  '2 - garagens',
#  '77,92 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '2 - garagens',
#  '154,00 - m²',
#  '2 - quartos',
#  '2 - suítes',
#  '2 - banheiros',
#  '2 - garagens',
#  '85,16 - m²',
#  '3 - quartos',
#  '3 - suítes',
#  '5 - banheiros',
#  '3 - garagens',
#  '250,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '1 - garagem',
#  '67,00 - m²',
#  '5 - quartos',
#  '3 - suítes',
#  '6 - banheiros',
#  '4 - garagens',
#  '294,00 - m²',
#  '1 - quarto',
#  '1 - suíte',
#  '1 - garagem',
#  '49,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '1 - garagem',
#  '74,00 - m²',
#  '4 - quartos',
#  '2 - suítes',
#  '4 - banheiros',
#  '2 - garagens',
#  '166,00 - m²',
#  '5 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '5 - garagens',
#  '220,75 - m²',
#  '3 - quartos',
#  '3 - suítes',
#  '3 - banheiros',
#  '3 - garagens',
#  '227,00 - m²',
#  '2 - quartos',
#  '1 - banheiro',
#  '1 - garagem',
#  '47,86 - m²',
#  '3 - quartos',
#  '2 - suítes',
#  '4 - banheiros',
#  '1 - garagem',
#  '176,00 - m²',
#  '1 - quarto',
#  '1 - banheiro',
#  '1 - garagem',
#  '35,00 - m²',
#  '4 - quartos',
#  '4 - suítes',
#  '5 - banheiros',
#  '2 - garagens',
#  '369,00 - m²',
#  '3 - quartos',
#  '2 - suítes',
#  '3 - banheiros',
#  '2 - garagens',
#  '171,00 - m²',
#  '3 - quartos',
#  '2 - suítes',
#  '3 - banheiros',
#  '3 - garagens',
#  '195,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '2 - garagens',
#  '199,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '2 - garagens',
#  '147,00 - m²',
#  '3 - quartos',
#  '3 - suítes',
#  '5 - banheiros',
#  '4 - garagens',
#  '247,00 - m²',
#  '4 - quartos',
#  '2 - suítes',
#  '4 - banheiros',
#  '4 - garagens',
#  '240,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '3 - banheiros',
#  '3 - garagens',
#  '258,00 - m²',
#  '3 - quartos',
#  '3 - suítes',
#  '4 - banheiros',
#  '4 - garagens',
#  '173,00 - m²',
#  '3 - quartos',
#  '3 - suítes',
#  '5 - banheiros',
#  '3 - garagens',
#  '153,00 - m²',
#  '3 - quartos',
#  '3 - suítes',
#  '3 - banheiros',
#  '3 - garagens',
#  '141,06 - m²',
#  '2 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '3 - garagens',
#  '95,00 - m²',
#  '900,00 - m²',
#  '777,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '2 - garagens',
#  '90,00 - m²',
#  '4 - quartos',
#  '2 - suítes',
#  '5 - banheiros',
#  '3 - garagens',
#  '218,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '2 - garagens',
#  '120,00 - m²',
#  '3 - quartos',
#  '3 - suítes',
#  '2 - banheiros',
#  '3 - garagens',
#  '293,58 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '2 - garagens',
#  '97,72 - m²',
#  '4 - quartos',
#  '4 - suítes',
#  '5 - banheiros',
#  '4 - garagens',
#  '344,79 - m²',
#  '15 - garagens',
#  '368,00 - m²',
#  '2 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '2 - garagens',
#  '67,67 - m²',
#  '2 - quartos',
#  '2 - suítes',
#  '2 - banheiros',
#  '2 - garagens',
#  '102,79 - m²',
#  '3 - quartos',
#  '3 - suítes',
#  '3 - banheiros',
#  '3 - garagens',
#  '227,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '1 - garagem',
#  '87,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '1 - banheiro',
#  '2 - garagens',
#  '97,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '1 - garagem',
#  '182,00 - m²',
#  '300,17 - m²',
#  '2 - quartos',
#  '2 - suítes',
#  '3 - banheiros',
#  '2 - garagens',
#  '256,25 - m²',
#  '2 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '1 - garagem',
#  '56,48 - m²',
#  '1 - quarto',
#  '1 - suíte',
#  '1 - banheiro',
#  '35,82 - m²',
#  '1 - quarto',
#  '1 - suíte',
#  '1 - banheiro',
#  '45,27 - m²',
#  '2 - quartos',
#  '53,27 - m²',
#  '2 - quartos',
#  '1 - banheiro',
#  '49,65 - m²',
#  '1 - quarto',
#  '1 - banheiro',
#  '23,32 - m²',
#  '1 - quarto',
#  '1 - banheiro',
#  '29,30 - m²',
#  '370,93 - m²',
#  '1 - banheiro',
#  '80,00 - m²',
#  '3 - quartos',
#  '3 - suítes',
#  '6 - banheiros',
#  '4 - garagens',
#  '257,00 - m²',
#  '3 - quartos',
#  '2 - suítes',
#  '3 - banheiros',
#  '2 - garagens',
#  '136,00 - m²',
#  '2 - quartos',
#  '1 - banheiro',
#  '1 - garagem',
#  '54,00 - m²',
#  '1 - quarto',
#  '1 - banheiro',
#  '34,00 - m²',
#  '3 - quartos',
#  '3 - suítes',
#  '5 - banheiros',
#  '4 - garagens',
#  '227,00 - m²',
#  '3 - banheiros',
#  '50 - garagens',
#  '640,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '2 - garagens',
#  '117,00 - m²',
#  '4 - quartos',
#  '1 - suíte',
#  '3 - banheiros',
#  '4 - garagens',
#  '435,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '4 - banheiros',
#  '2 - garagens',
#  '128,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '3 - banheiros',
#  '1 - garagem',
#  '182,00 - m²',
#  '3 - quartos',
#  '3 - suítes',
#  '4 - banheiros',
#  '3 - garagens',
#  '188,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '3 - banheiros',
#  '2 - garagens',
#  '91,58 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '4 - banheiros',
#  '2 - garagens',
#  '150,02 - m²',
#  '2 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '1 - garagem',
#  '70,13 - m²',
#  '1 - banheiro',
#  '38,48 - m²',
#  '3 - quartos',
#  '3 - suítes',
#  '3 - banheiros',
#  '4 - garagens',
#  '309,19 - m²',
#  '3 - quartos',
#  '3 - suítes',
#  '3 - banheiros',
#  '3 - garagens',
#  '212,71 - m²',
#  '4 - quartos',
#  '4 - suítes',
#  '7 - banheiros',
#  '6 - garagens',
#  '513,86 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '3 - banheiros',
#  '2 - garagens',
#  '170,00 - m²',
#  '3 - quartos',
#  '3 - suítes',
#  '6 - banheiros',
#  '4 - garagens',
#  '430,00 - m²',
#  '3 - quartos',
#  '3 - suítes',
#  '5 - banheiros',
#  '2 - garagens',
#  '155,00 - m²',
#  '2 - quartos',
#  '2 - suítes',
#  '3 - banheiros',
#  '2 - garagens',
#  '103,00 - m²',
#  '2 - quartos',
#  '2 - suítes',
#  '3 - banheiros',
#  '2 - garagens',
#  '103,00 - m²',
#  '4 - quartos',
#  '2 - suítes',
#  '2 - garagens',
#  '120,00 - m²',
#  '2 - quartos',
#  '1 - suíte',
#  '1 - banheiro',
#  '1 - garagem',
#  '63,00 - m²',
#  '2 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '2 - garagens',
#  '70,00 - m²',
#  '4 - quartos',
#  '4 - suítes',
#  '5 - banheiros',
#  '2 - garagens',
#  '331,80 - m²',
#  '4 - quartos',
#  '4 - suítes',
#  '5 - banheiros',
#  '3 - garagens',
#  '151,00 - m²',
#  '4 - quartos',
#  '4 - suítes',
#  '5 - banheiros',
#  '2 - garagens',
#  '144,00 - m²',
#  '3 - quartos',
#  '3 - suítes',
#  '4 - banheiros',
#  '2 - garagens',
#  '138,00 - m²',
#  '3 - quartos',
#  '3 - suítes',
#  '4 - banheiros',
#  '2 - garagens',
#  '127,00 - m²',
#  '4 - quartos',
#  '4 - suítes',
#  '5 - banheiros',
#  '4 - garagens',
#  '315,11 - m²',
#  '2 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '2 - garagens',
#  '75,00 - m²',
#  '2 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '1 - garagem',
#  '54,00 - m²',
#  '2 - quartos',
#  '1 - banheiro',
#  '1 - garagem',
#  '53,91 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '2 - garagens',
#  '154,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '3 - banheiros',
#  '2 - garagens',
#  '131,00 - m²',
#  '1 - quarto',
#  '1 - banheiro',
#  '1 - garagem',
#  '47,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '3 - banheiros',
#  '2 - garagens',
#  '119,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '3 - banheiros',
#  '2 - garagens',
#  '119,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '3 - banheiros',
#  '2 - garagens',
#  '195,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '3 - banheiros',
#  '2 - garagens',
#  '131,00 - m²',
#  '3 - quartos',
#  '3 - suítes',
#  '4 - banheiros',
#  '2 - garagens',
#  '120,40 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '1 - garagem',
#  '61,00 - m²',
#  '2 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '1 - garagem',
#  '68,00 - m²',
#  '3 - quartos',
#  '3 - suítes',
#  '5 - banheiros',
#  '4 - garagens',
#  '207,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '1 - garagem',
#  '79,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '1 - garagem',
#  '87,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '3 - banheiros',
#  '2 - garagens',
#  '108,92 - m²',
#  '2 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '1 - garagem',
#  '71,00 - m²',
#  '3 - banheiros',
#  '10 - garagens',
#  '600,00 - m²',
#  '2 - quartos',
#  '1 - suíte',
#  '1 - banheiro',
#  '1 - garagem',
#  '66,00 - m²',
#  '2 - quartos',
#  '2 - suítes',
#  '3 - banheiros',
#  '2 - garagens',
#  '126,00 - m²',
#  '1 - quarto',
#  '1 - banheiro',
#  '1 - garagem',
#  '32,00 - m²',
#  '1 - banheiro',
#  '38,00 - m²',
#  '1 - quarto',
#  '1 - banheiro',
#  '72,00 - m²',
#  '2 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '2 - garagens',
#  '73,00 - m²',
#  '4 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '2 - garagens',
#  '120,00 - m²',
#  '2 - quartos',
#  '1 - suíte',
#  '3 - banheiros',
#  '2 - garagens',
#  '75,00 - m²',
#  '1 - quarto',
#  '1 - suíte',
#  '2 - banheiros',
#  '1 - garagem',
#  '49,00 - m²',
#  '3 - quartos',
#  '3 - suítes',
#  '4 - banheiros',
#  '3 - garagens',
#  '160,00 - m²',
#  '2 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '2 - garagens',
#  '91,00 - m²',
#  '2 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '1 - garagem',
#  '68,00 - m²',
#  '754,00 - m²',
#  '2 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '1 - garagem',
#  '3 - quartos',
#  '3 - suítes',
#  '4 - banheiros',
#  '3 - garagens',
#  '153,00 - m²',
#  '1 - quarto',
#  '1 - banheiro',
#  '18,00 - m²',
#  '1 - quarto',
#  '1 - banheiro',
#  '34,00 - m²',
#  '3 - quartos',
#  '3 - suítes',
#  '4 - banheiros',
#  '3 - garagens',
#  '160,00 - m²',
#  '3 - quartos',
#  '3 - suítes',
#  '3 - banheiros',
#  '2 - garagens',
#  '138,88 - m²',
#  '3 - quartos',
#  '3 - suítes',
#  '3 - banheiros',
#  '2 - garagens',
#  '138,00 - m²',
#  '3 - quartos',
#  '3 - suítes',
#  '4 - banheiros',
#  '2 - garagens',
#  '160,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '3 - banheiros',
#  '2 - garagens',
#  '103,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '3 - banheiros',
#  '1 - garagem',
#  '156,00 - m²',
#  '4 - quartos',
#  '2 - suítes',
#  '4 - banheiros',
#  '3 - garagens',
#  '226,00 - m²',
#  '4 - quartos',
#  '2 - suítes',
#  '4 - banheiros',
#  '3 - garagens',
#  '226,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '3 - banheiros',
#  '2 - garagens',
#  '155,00 - m²',
#  '3 - quartos',
#  '3 - suítes',
#  '4 - banheiros',
#  '2 - garagens',
#  '119,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '1 - garagem',
#  '86,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '1 - garagem',
#  '106,00 - m²',
#  '3 - quartos',
#  '2 - banheiros',
#  '1 - garagem',
#  '99,00 - m²',
#  '3 - quartos',
#  '3 - suítes',
#  '3 - banheiros',
#  '2 - garagens',
#  '136,46 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '2 - garagens',
#  '97,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '3 - banheiros',
#  '2 - garagens',
#  '97,00 - m²',
#  '2 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '1 - garagem',
#  '80,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '3 - banheiros',
#  '1 - garagem',
#  '119,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '3 - banheiros',
#  '1 - garagem',
#  '111,00 - m²',
#  '4 - quartos',
#  '1 - suíte',
#  '4 - banheiros',
#  '2 - garagens',
#  '122,00 - m²',
#  '4 - quartos',
#  '1 - suíte',
#  '4 - banheiros',
#  '2 - garagens',
#  '123,00 - m²',
#  '4 - quartos',
#  '1 - suíte',
#  '4 - banheiros',
#  '2 - garagens',
#  '123,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '3 - banheiros',
#  '2 - garagens',
#  '106,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '3 - banheiros',
#  '2 - garagens',
#  '106,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '5 - banheiros',
#  '2 - garagens',
#  '236,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '5 - banheiros',
#  '2 - garagens',
#  '236,00 - m²',
#  '4 - quartos',
#  '2 - suítes',
#  '3 - banheiros',
#  '4 - garagens',
#  '178,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '2 - garagens',
#  '71,32 - m²',
#  '1 - quarto',
#  '1 - suíte',
#  '2 - banheiros',
#  '1 - garagem',
#  '99,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '3 - banheiros',
#  '2 - garagens',
#  '153,00 - m²',
#  '5 - quartos',
#  '2 - suítes',
#  '5 - banheiros',
#  '10 - garagens',
#  '650,00 - m²',
#  '4 - quartos',
#  '4 - suítes',
#  '5 - banheiros',
#  '3 - garagens',
#  '295,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '1 - garagem',
#  '3 - quartos',
#  '3 - suítes',
#  '5 - banheiros',
#  '194,00 - m²',
#  '1 - quarto',
#  '1 - banheiro',
#  '33,00 - m²',
#  '3 - quartos',
#  '1 - banheiro',
#  '1 - garagem',
#  '60,15 - m²',
#  '4 - quartos',
#  '4 - suítes',
#  '6 - banheiros',
#  '4 - garagens',
#  '260,00 - m²',
#  '2 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '2 - garagens',
#  '3 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '2 - garagens',
#  '142,00 - m²',
#  '1 - quarto',
#  '1 - banheiro',
#  '41,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '2 - garagens',
#  '142,00 - m²',
#  '2 - quartos',
#  '1 - suíte',
#  '3 - banheiros',
#  '1 - garagem',
#  '102,34 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '3 - banheiros',
#  '2 - garagens',
#  '210,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '3 - banheiros',
#  '2 - garagens',
#  '170,00 - m²',
#  '2 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '2 - garagens',
#  '113,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '4 - banheiros',
#  '2 - garagens',
#  '140,00 - m²',
#  '4 - quartos',
#  '2 - suítes',
#  '4 - banheiros',
#  '1 - garagem',
#  '184,00 - m²',
#  '1 - quarto',
#  '1 - banheiro',
#  '31,00 - m²',
#  '2 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '1 - garagem',
#  '68,00 - m²',
#  '4 - quartos',
#  '4 - suítes',
#  '5 - banheiros',
#  '3 - garagens',
#  '284,00 - m²',
#  '2 - quartos',
#  '1 - banheiro',
#  '1 - garagem',
#  '55,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '1 - garagem',
#  '104,00 - m²',
#  '4 - quartos',
#  '2 - suítes',
#  '5 - banheiros',
#  '1 - garagem',
#  '255,00 - m²',
#  '3 - quartos',
#  '2 - suítes',
#  '3 - banheiros',
#  '2 - garagens',
#  '103,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '1 - garagem',
#  '65,00 - m²',
#  '2 - quartos',
#  '1 - suíte',
#  '2 - banheiros',
#  '1 - garagem',
#  '70,00 - m²',
#  '3 - quartos',
#  '1 - suíte',
#  '3 - banheiros',
#  ...]

# %%
location_list_neighborhood = site.find_all('div','info')
#print(price_list)

for location in location_list_neighborhood:
    location_neighborhood = location.find('h5').text
    print(location_neighborhood)
# Out:
# Sítio Cercado
# Centro
# Praia Brava
# Pioneiros
# Barra Sul
# Mossunguê
# Centro
# Cabral
# Barra Sul
# Santa Felicidade
# Campo Comprido
# Portão
# Hauer
# Hauer
# Butiatuvinha
# Capão Raso
# Água Verde
# Vista Alegre
# Bacacheri
# Juvevê
# Cristo Rei
# Mercês
# Água Verde
# Abranches
# Centro
# Cabral
# Centro
# Cabral
# Boa Vista
# Santo Inácio
# Santo Inácio
# Bigorrilho
# Seminário
# Campo Comprido
# Juvevê
# Mercês
# Água Verde
# Mercês
# Portão
# Bom Retiro
# Sítio Cercado
# Bom Retiro
# Xaxim
# Boqueirão
# Campina do Siqueira
# Mercês
# Água Verde
# Portão
# Santo Inácio
# Água Verde
# Novo Mundo
# Cidade Industrial
# Novo Mundo
# Vila Izabel
# Sítio Cercado
# Bom Retiro
# Guaíra
# Butiatuvinha
# Portão
# Portão
# Uberaba
# Vista Alegre
# Cabral
# Juvevê
# Cidade Industrial
# Seminário
# Água Verde
# Seminário
# Água Verde
# Santa Quitéria
# Novo Mundo
# Xaxim
# Água Verde
# Capão Raso
# Ahú
# Ahú
# Cabral
# Bacacheri
# Centro
# Centro
# Vila Izabel
# Cristo Rei
# Cristo Rei
# Mercês
# Portão
# Bigorrilho
# Água Verde
# Portão
# Portão
# Portão
# Portão
# Portão
# Portão
# Portão
# Centro
# Batel
# Alto da Glória
# Água Verde
# Vila Izabel
# Campo Comprido
# Cidade Industrial
# Bairro Alto
# Portão
# Cidade Industrial
# Mercês
# Batel
# Portão
# Portão
# Centro
# Água Verde
# Mossunguê
# Mossunguê
# Batel
# Lindóia
# Ecoville
# Água Verde
# Vila Izabel
# Batel
# Cabral
# Bigorrilho
# Bigorrilho
# Centro
# Pioneiros
# Centro
# Centro
# Meia Praia
# Centro
# Santa Quitéria
# Rebouças
# Cristo Rei
# Campina do Siqueira
# Portão
# Bigorrilho
# Santa Felicidade
# Santa Felicidade
# Portão
# Portão
# Mercês
# Cidade Industrial
# Bigorrilho
# Água Verde
# Bigorrilho
# Cristo Rei
# Cajuru
# Vila Izabel
# São Braz
# Mercês
# Vila Izabel
# Vila Izabel
# Batel
# Portão
# Santa Quitéria
# Cabral
# Alto da Glória
# Boa Vista
# Mossunguê
# Água Verde
# Capão Raso
# Augusta
# Novo Mundo
# Água Verde
# Rebouças
# Rebouças
# Mossunguê
# Uberaba
# Uberaba
# Cabral
# Vila Izabel
# Santa Felicidade
# Água Verde
# Água Verde
# Santa Felicidade
# Mercês
# Bacacheri
# Bacacheri
# Bacacheri
# Bigorrilho
# Ahú
# Ahú
# Juvevê
# Juvevê
# Juvevê
# Vila Izabel
# Vila Izabel
# Vila Izabel
# Xaxim
# Xaxim
# Ecoville
# Ecoville
# Ariribá
# Santo Inácio
# Cristo Rei
# Ecoville
# São Lourenço
# Santo Inácio
# Vila Izabel
# Bigorrilho
# Centro
# Tingui
# Ecoville
# Cabral
# Emiliano Perneta
# Portão
# Emiliano Perneta
# Centro
# Santa Cândida
# Lindóia
# Alto da Rua XV
# Santa Felicidade
# Mossunguê
# Portão
# Jardim Botânico
# Água Verde
# Alto da Glória
# Vila Izabel
# Mossunguê
# Vila Izabel
# Guaíra
# Batel
# Batel
# Uberaba
# Uberaba
# Uberaba
# Portão
# Centro
# Praia Brava
# Barra Sul
# Itaipava
# Santa Regina
# Santa Regina
# Santa Regina
# Santa Regina
# Vila Izabel
# Centro
# Centro
# Centro
# Praia Brava
# Praia Brava
# Santa Regina
# Centro
# Centro
# Praia do Estaleirinho
# Centro
# Centro
# Centro
# Centro
# Barra Sul
# Centro
# Praia Brava
# Praia Brava
# Centro
# Praia Brava
# Centro
# Bigorrilho
# Bigorrilho
# Campo Comprido
# Mossunguê
# Campo Comprido
# Barra Sul
# Pioneiros
# Mossunguê
# Centro
# Centro
# Água Verde
# Barra Sul
# Praia de Guaratuba
# Centro
# Pioneiros
# Ariribá
# Centro
# Centro
# Pioneiros
# Centro
# Bigorrilho
# Santa Felicidade
# Água Verde
# Santa Felicidade
# Água Verde
# Praia Brava
# Cabral
# Batel
# Centro
# Rio Pequeno
# Rio Pequeno
# São Francisco de Assis
# Centro
# Centro
# Pinheirinho
# Vila Izabel
# Centro
# Centro
# Santa Regina
# Água Verde
# Centro
# Campina do Siqueira
# Centro
# Seminário
# Portão
# Centro
# Campo Comprido
# Centro
# Santa Regina
# Centro
# Santa Felicidade
# Novo Mundo
# Boqueirão
# Água Verde
# Centro
# Areias
# São Vicente
# Centro
# Praia Brava
# Batel
# Batel
# Água Verde
# Água Verde
# Cabral
# Água Verde
# Praia do Estaleirinho
# Água Verde
# Água Verde
# Champagnat
# Água Verde
# Praia das Taquaras
# Centro
# Centro
# Centro
# Centro
# Batel
# Centro
# Alto da Glória
# Vila Izabel
# Portão
# Praia Brava
# Juvevê
# Capão Raso
# Taboão
# Centro
# Centro
# Fazenda
# Centro
# Centro
# augusta
# Água Verde
# Capão Raso
# Uberaba
# Água Verde
# Mercês
# Carioca
# Água Verde

# %%
location_list_city = site.find_all('div','info')
#print(price_list)

for location in location_list_city:
    location_city = location.find('h4').text
    print(location_city)
# Out:
# Curitiba
# Balneario Camboriu
# Itajai
# Balneario Camboriu
# Balneario Camboriu
# Curitiba
# Balneario Camboriu
# Curitiba
# Balneario Camboriu
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Balneario Camboriu
# Balneario Camboriu
# Balneario Camboriu
# Balneario Camboriu
# Itapema
# Balneario Camboriu
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Balneario Camboriu
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Pinhais
# Curitiba
# Pinhais
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Balneario Camboriu
# Itajai
# Balneario Camboriu
# Itajai
# Camboriu
# Camboriu
# Camboriu
# Camboriu
# Curitiba
# Camboriu
# Camboriu
# Camboriu
# Itajai
# Itajai
# Camboriu
# Balneario Camboriu
# Camboriu
# Balneario Camboriu
# Balneario Camboriu
# Balneario Camboriu
# Camboriu
# Camboriu
# Balneario Camboriu
# Balneario Camboriu
# Itajai
# Itajai
# Balneario Camboriu
# Itajai
# Balneario Camboriu
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Balneario Camboriu
# Balneario Camboriu
# Curitiba
# Balneario Camboriu
# Balneario Camboriu
# Curitiba
# Balneario Camboriu
# Guaratuba
# Balneario Camboriu
# Balneario Camboriu
# Balneario Camboriu
# Balneario Camboriu
# Balneario Camboriu
# Balneario Camboriu
# Balneario Camboriu
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Itajai
# Curitiba
# Curitiba
# Balneario Camboriu
# Camboriu
# Camboriu
# Camboriu
# Balneario Camboriu
# Balneario Camboriu
# Curitiba
# Curitiba
# Balneario Camboriu
# Balneario Camboriu
# Camboriu
# Curitiba
# Balneario Camboriu
# Curitiba
# Camboriu
# Curitiba
# Curitiba
# Balneario Camboriu
# Curitiba
# Balneario Camboriu
# Camboriu
# Balneario Camboriu
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Camboriu
# Camboriu
# Itajai
# Curitiba
# Itajai
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Balneario Camboriu
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Balneario Camboriu
# Balneario Camboriu
# Balneario Camboriu
# Curitiba
# Curitiba
# Curitiba
# Balneario Camboriu
# Curitiba
# Curitiba
# Curitiba
# Itajai
# Curitiba
# Curitiba
# Curitiba
# Camboriu
# Balneario Camboriu
# Itajai
# Balneario Camboriu
# Balneario Camboriu
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# Curitiba
# São José dos Pinhais
# Curitiba
